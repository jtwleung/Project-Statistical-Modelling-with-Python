# %%
# imports

import requests
import os
import pandas as pd

# %% [markdown]
# # Foursquare

# %% [markdown]
# ## Julie's Notes:
# From Foursquare categories list (https://location.foursquare.com/places/docs/categories), I compiled the following categories (sometimes combined) which I will send with the "categories" query parameter for each bike station location:
#
# <img src='../images/foursquare_categories.png'>
#
# These decisions attempt to optimize the tension between API call limit (40,000) and response item limit (maxxes out at 50 items).

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
# Pull my FOURSQUARE API key into a variable
FOURSQUARE_KEY = os.getenv('FOURSQUARE_API_KEY')

# %%
# Function Definitions

# Define function that will make the GET request to Foursquare
#def yelp_get_request_business_search(station_latitude, station_longitude, radius, categories, API_KEY):
def foursquare_get_request_place_search(station_latitude, station_longitude, radius, categories, API_KEY):

    base_foursquare_endpoint = 'https://api.foursquare.com/v3'
    place_search = '/places/search'

    # Default Query Parameters for all our GET requests, that aren't otherwise passed in
    limit = 50  # Always get as many as allowed
    sort_by = 'distance'  # Foursquare says 'ratings' is a valid sort option, but I haven't seen evidence in their payload that they have ratings!

    # Craft the request_url:
    request_url = base_foursquare_endpoint + place_search + \
    '?' + \
    'll=' + str(station_latitude) + ',' + str(station_longitude) + \
    '&radius=' + str(radius) + \
    '&categories=' + categories + \
    '&limit=' + str(limit) + \
    '&sort_by=' + sort_by

    header_dict = {
    'accept': 'application/json',
    'Authorization' : FOURSQUARE_KEY
    }
    
    # DEBUG
    #print(f"Inside foursquare_get_request: request_url = {request_url}, header_dict = {header_dict}")
    print(f"     Calling API: request_url = {request_url}")

    # Make the call, get response out
    response = requests.get(request_url, headers=header_dict)

    # Return the payload_dict to caller
    return response.json()
    

# Define function that will create the default fsq_dict for each GET request:
def create_default_fsqdict(fsqdict):
    fsqdict.clear()
    fsqdict['station_id']= []
    fsqdict['place_id'] = []
    fsqdict['name'] = []
    fsqdict['distance'] = []
    fsqdict['address'] = []
    fsqdict['city'] = []
    fsqdict['postal'] = []
    fsqdict['category_id'] = []
    fsqdict['category_name'] = []
    fsqdict['query_categories'] = []
    fsqdict['query_category_text'] = []


# Define function that will parse the JSON-formatted response
def fsqdict_from_response(stationid, fsqdict, jsonpayload, query_categories, query_category_text):

    #print(f"I'm in fsqdict_from_response, and fsqdict is:\n{fsqdict}")
    # Ternary operators are required because my testing indicated some entries are missing 'postcode'.
    # Given the risk of this erroring-out on 425 * 6 = 2550 calls, adding ternary operators to check for presence, on name/distance/address/city/postcode
    results_array = jsonpayload['results']
    for result in results_array:
        fsqdict['station_id'].append(stationid)
        fsqdict['place_id'].append(result['fsq_id'])
        fsqdict['name'].append(result['name'] if 'name' in result else 'N/A')
        fsqdict['distance'].append(result['distance'] if 'distance' in result else NaN)
        fsqdict['address'].append(result['location']['address'] if 'address' in result['location'] else 'N/A')
        fsqdict['city'].append(result['location']['locality'] if 'locality' in result['location'] else 'N/A')
        fsqdict['postal'].append(result['location']['postcode'] if 'postcode' in result['location'] else 'N/A')
        
        categories_array = result['categories']
        id_string = ''
        categoryname_string = ''
        for entry in categories_array:
            id_string += str(entry['id']) + '|'
            categoryname_string += entry['name'] + '|'
        
        id_string = id_string[:-1]
        categoryname_string = categoryname_string[:-1]
        fsqdict['category_id'].append(id_string)
        fsqdict['category_name'].append(categoryname_string)
        fsqdict['query_categories'].append(query_categories)
        fsqdict['query_category_text'].append(query_category_text)

    return fsqdict

# %%
# # Test with static JSON file:  Delete me after
# import json
# json_file = open('C:/Users/raref/Lighthouse/W05D02_Data_Wrangling_Challenge_Walkthrough/Other_data_types_exercise/payload_postman_cambie_fsq_coffee.json', 'r')
# payload_dict = json.load(json_file)
# payload_dict
# Out:
# {'results': [{'fsq_id': '4b1db335f964a520211424e3',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13263,
#      'name': 'Japanese Restaurant',
#      'short_name': 'Japanese',
#      'plural_name': 'Japanese Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 96,
#    'geocodes': {'main': {'latitude': 49.263328, 'longitude': -123.11402},
#     'roof': {'latitude': 49.263328, 'longitude': -123.11402}},
#    'link': '/v3/places/4b1db335f964a520211424e3',
#    'location': {'address': '451W Broadway W',
#     'country': 'CA',
#     'cross_street': 'at Cambie St',
#     'formatted_address': '451W Broadway W (at Cambie St), Vancouver BC V5Y 1R4',
#     'locality': 'Vancouver',
#     'postcode': 'V5Y 1R4',
#     'region': 'BC'},
#    'name': 'Marulilu Cafe',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '54b2b74b498ee334f9cb197e',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 160,
#    'geocodes': {'main': {'latitude': 49.263864, 'longitude': -123.115282},
#     'roof': {'latitude': 49.263864, 'longitude': -123.115282}},
#    'link': '/v3/places/54b2b74b498ee334f9cb197e',
#    'location': {'address': '510 8th Ave W',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '510 8th Ave W, Vancouver BC V5Z 1C5',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 1C5',
#     'region': 'BC'},
#    'name': 'WFM Coffee Bar',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '63ec484f81ae292c32042b9b',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 197,
#    'geocodes': {'drop_off': {'latitude': 49.264225, 'longitude': -123.114711},
#     'main': {'latitude': 49.264224, 'longitude': -123.114502},
#     'roof': {'latitude': 49.264224, 'longitude': -123.114502}},
#    'link': '/v3/places/63ec484f81ae292c32042b9b',
#    'location': {'address': '2378 Cambie St',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '2378 Cambie St, Vancouver BC V5Z 2T8',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 2T8',
#     'region': 'BC'},
#    'name': 'Artigiano',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '79f1e0e1fb0e42d55c5cd31b',
#    'categories': [{'id': 13003,
#      'name': 'Bar',
#      'short_name': 'Bar',
#      'plural_name': 'Bars',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'}},
#     {'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 216,
#    'geocodes': {'drop_off': {'latitude': 49.263899, 'longitude': -123.112016},
#     'main': {'latitude': 49.263663, 'longitude': -123.112021},
#     'roof': {'latitude': 49.263663, 'longitude': -123.112021}},
#    'link': '/v3/places/79f1e0e1fb0e42d55c5cd31b',
#    'location': {'address': '350 8th Ave W',
#     'country': 'CA',
#     'formatted_address': '350 8th Ave W, Vancouver BC',
#     'locality': 'Vancouver',
#     'region': 'BC'},
#    'name': 'Jammer Cafe Motors Inc',
#    'related_places': {}},
#   {'fsq_id': '4be48099910020a134ced114',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 223,
#    'geocodes': {'main': {'latitude': 49.260796, 'longitude': -123.116318},
#     'roof': {'latitude': 49.260796, 'longitude': -123.116318}},
#    'link': '/v3/places/4be48099910020a134ced114',
#    'location': {'address': '555 12th Ave W',
#     'address_extended': '# 113',
#     'country': 'CA',
#     'cross_street': 'at Cambie St in City Square Shopping Centre',
#     'formatted_address': '555 12th Ave W (at Cambie St in City Square Shopping Centre), Vancouver BC V5Z 3X7',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 3X7',
#     'region': 'BC'},
#    'name': 'Cultured Coffee & Tea',
#    'related_places': {'parent': {'fsq_id': '4aa7fd69f964a5208e4e20e3',
#      'categories': [{'id': 17114,
#        'name': 'Shopping Mall',
#        'short_name': 'Mall',
#        'plural_name': 'Shopping Malls',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#         'suffix': '.png'}}],
#      'name': 'City Square Shopping Centre'}},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4aa98676f964a520105420e3',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 225,
#    'geocodes': {'drop_off': {'latitude': 49.263256, 'longitude': -123.11724},
#     'main': {'latitude': 49.263077, 'longitude': -123.117243},
#     'roof': {'latitude': 49.263077, 'longitude': -123.117243}},
#    'link': '/v3/places/4aa98676f964a520105420e3',
#    'location': {'address': '590 Broadway W',
#     'country': 'CA',
#     'cross_street': 'at Ash St',
#     'formatted_address': '590 Broadway W (at Ash St), Vancouver BC V5Z 1E9',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 1E9',
#     'region': 'BC'},
#    'name': 'Elysian Coffee Broadway',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': 'd7f6f4cc6fdb4672865838d0',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 263,
#    'geocodes': {'main': {'latitude': 49.263128, 'longitude': -123.117896},
#     'roof': {'latitude': 49.263128, 'longitude': -123.117896}},
#    'link': '/v3/places/d7f6f4cc6fdb4672865838d0',
#    'location': {'address': '604 Broadway W',
#     'address_extended': '# 400',
#     'country': 'CA',
#     'formatted_address': '604 Broadway W, Vancouver BC V5Z 1G1',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 1G1',
#     'region': 'BC'},
#    'name': 'Granville Island Coffee Co',
#    'related_places': {}},
#   {'fsq_id': '59e17bf46f706a79a2e1a28f',
#    'categories': [{'id': 13033,
#      'name': 'Bubble Tea Shop',
#      'short_name': 'Bubble Tea',
#      'plural_name': 'Bubble Tea Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#       'suffix': '.png'}},
#     {'id': 13036,
#      'name': 'Tea Room',
#      'short_name': 'Tea Room',
#      'plural_name': 'Tea Rooms',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 275,
#    'geocodes': {'drop_off': {'latitude': 49.260069, 'longitude': -123.115015},
#     'main': {'latitude': 49.260064, 'longitude': -123.114715},
#     'roof': {'latitude': 49.260064, 'longitude': -123.114715}},
#    'link': '/v3/places/59e17bf46f706a79a2e1a28f',
#    'location': {'address': '2828 Cambie St',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '2828 Cambie St, Vancouver BC V5Z 2V5',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 2V5',
#     'region': 'BC'},
#    'name': 'Share Tea',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4b8749a7f964a5203eba31e3',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13039,
#      'name': 'Deli',
#      'short_name': 'Deli',
#      'plural_name': 'Delis',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'}},
#     {'id': 13334,
#      'name': 'Sandwich Spot',
#      'short_name': 'Sandwich Spot',
#      'plural_name': 'Sandwich Spots',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 289,
#    'geocodes': {'drop_off': {'latitude': 49.263741, 'longitude': -123.11094},
#     'main': {'latitude': 49.263729, 'longitude': -123.110729},
#     'roof': {'latitude': 49.263729, 'longitude': -123.110729}},
#    'link': '/v3/places/4b8749a7f964a5203eba31e3',
#    'location': {'address': '2408 Alberta St',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '2408 Alberta St, Vancouver BC V5Y 3Y6',
#     'locality': 'Vancouver',
#     'postcode': 'V5Y 3Y6',
#     'region': 'BC'},
#    'name': 'Cafe Tica',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '5c02fb85535d6f002c3d812c',
#    'categories': [{'id': 13002,
#      'name': 'Bakery',
#      'short_name': 'Bakery',
#      'plural_name': 'Bakeries',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#       'suffix': '.png'}},
#     {'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 301,
#    'geocodes': {'main': {'latitude': 49.262854, 'longitude': -123.11033},
#     'roof': {'latitude': 49.262854, 'longitude': -123.11033}},
#    'link': '/v3/places/5c02fb85535d6f002c3d812c',
#    'location': {'address': '236 Broadway W',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '236 Broadway W, Vancouver BC V5Y 1P6',
#     'locality': 'Vancouver',
#     'postcode': 'V5Y 1P6',
#     'region': 'BC'},
#    'name': 'Foret Noire Patisserie',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '58cc6ce6af7d175e606eaf83',
#    'categories': [{'id': 13036,
#      'name': 'Tea Room',
#      'short_name': 'Tea Room',
#      'plural_name': 'Tea Rooms',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 321,
#    'geocodes': {'drop_off': {'latitude': 49.264992, 'longitude': -123.116133},
#     'main': {'latitude': 49.265239, 'longitude': -123.11613},
#     'roof': {'latitude': 49.265239, 'longitude': -123.11613}},
#    'link': '/v3/places/58cc6ce6af7d175e606eaf83',
#    'location': {'address': '511 7th Ave W',
#     'address_extended': 'Unit 117',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '511 7th Ave W, Vancouver BC V5Z 4R2',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 4R2',
#     'region': 'BC'},
#    'name': 'Shaktea',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '61f0a211e51e08606aad7c76',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 324,
#    'geocodes': {'drop_off': {'latitude': 49.264997, 'longitude': -123.116537},
#     'main': {'latitude': 49.265229, 'longitude': -123.116534},
#     'roof': {'latitude': 49.265229, 'longitude': -123.116534}},
#    'link': '/v3/places/61f0a211e51e08606aad7c76',
#    'location': {'address': '511 7th Ave W',
#     'address_extended': 'Unit 117',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '511 7th Ave W, Vancouver BC V5Z 4R2',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 4R2',
#     'region': 'BC'},
#    'name': 'Cafe & Life Co',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4c75baefdb52b1f7c5b979dc',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 336,
#    'geocodes': {'main': {'latitude': 49.26473, 'longitude': -123.116978},
#     'roof': {'latitude': 49.26473, 'longitude': -123.116978}},
#    'link': '/v3/places/4c75baefdb52b1f7c5b979dc',
#    'location': {'address': '2310 Ash St',
#     'country': 'CA',
#     'cross_street': 'at W 7th Ave',
#     'formatted_address': '2310 Ash St (at W 7th Ave), Vancouver BC V5Z 3C2',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 3C2',
#     'region': 'BC'},
#    'name': 'Caffe Cittadella',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4c054ca239d476b01fad32a7',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 385,
#    'geocodes': {'main': {'latitude': 49.262578, 'longitude': -123.119471},
#     'roof': {'latitude': 49.262578, 'longitude': -123.119471}},
#    'link': '/v3/places/4c054ca239d476b01fad32a7',
#    'location': {'address': '675 10th Ave W',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '675 10th Ave W, Vancouver BC V5Z 1L3',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 1L3',
#     'region': 'BC'},
#    'name': 'Java Express',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4aee5795f964a520a0d321e3',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 400,
#    'geocodes': {'drop_off': {'latitude': 49.263295, 'longitude': -123.119629},
#     'main': {'latitude': 49.263448, 'longitude': -123.119627},
#     'roof': {'latitude': 49.263448, 'longitude': -123.119627}},
#    'link': '/v3/places/4aee5795f964a520a0d321e3',
#    'location': {'address': '695 Broadway W',
#     'country': 'CA',
#     'cross_street': 'at Heather St.',
#     'formatted_address': '695 Broadway W (at Heather St.), Vancouver BC V5Z 1G6',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 1G6',
#     'region': 'BC'},
#    'name': 'Blenz Coffee',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': 'cfefae1368db4e638580f784',
#    'categories': [{'id': 13001,
#      'name': 'Bagel Shop',
#      'short_name': 'Bagels',
#      'plural_name': 'Bagel Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bagels_',
#       'suffix': '.png'}},
#     {'id': 13002,
#      'name': 'Bakery',
#      'short_name': 'Bakery',
#      'plural_name': 'Bakeries',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#       'suffix': '.png'}},
#     {'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 408,
#    'geocodes': {'drop_off': {'latitude': 49.263108, 'longitude': -123.108917},
#     'main': {'latitude': 49.263332, 'longitude': -123.108911},
#     'roof': {'latitude': 49.263332, 'longitude': -123.108911}},
#    'link': '/v3/places/cfefae1368db4e638580f784',
#    'location': {'address': '191 Broadway W',
#     'country': 'CA',
#     'formatted_address': '191 Broadway W, Vancouver BC V5Y 1P4',
#     'locality': 'Vancouver',
#     'postcode': 'V5Y 1P4',
#     'region': 'BC'},
#    'name': 'Simit Bakery',
#    'related_places': {}},
#   {'fsq_id': '4aec909ff964a520ccc821e3',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 430,
#    'geocodes': {'main': {'latitude': 49.263724, 'longitude': -123.108701},
#     'roof': {'latitude': 49.263724, 'longitude': -123.108701}},
#    'link': '/v3/places/4aec909ff964a520ccc821e3',
#    'location': {'address': '156 8th Ave W',
#     'country': 'CA',
#     'cross_street': 'btwn Columbia & Manitoba St',
#     'formatted_address': '156 8th Ave W (btwn Columbia & Manitoba St), Vancouver BC V5Y 1N2',
#     'locality': 'Vancouver',
#     'postcode': 'V5Y 1N2',
#     'region': 'BC'},
#    'name': 'Milano Coffee',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '5a31538260d11b06bc47c475',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 524,
#    'geocodes': {'drop_off': {'latitude': 49.263062, 'longitude': -123.107198},
#     'main': {'latitude': 49.263182, 'longitude': -123.107195},
#     'roof': {'latitude': 49.263182, 'longitude': -123.107195}},
#    'link': '/v3/places/5a31538260d11b06bc47c475',
#    'location': {'address': '112 W Broadway',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '112 W Broadway, Vancouver BC',
#     'locality': 'Vancouver',
#     'region': 'BC'},
#    'name': 'Modus Coffee',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4aa9212ff964a520185220e3',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'ab4c54c0-d68a-012e-5619-003048cad9da',
#      'name': 'Starbucks'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 529,
#    'geocodes': {'main': {'latitude': 49.267226, 'longitude': -123.112973},
#     'roof': {'latitude': 49.267226, 'longitude': -123.112973}},
#    'link': '/v3/places/4aa9212ff964a520185220e3',
#    'location': {'address': '2035 Yukon St',
#     'country': 'CA',
#     'cross_street': 'at W 2nd Ave',
#     'formatted_address': '2035 Yukon St (at W 2nd Ave), Vancouver BC V5Y 3W3',
#     'locality': 'Vancouver',
#     'postcode': 'V5Y 3W3',
#     'region': 'BC'},
#    'name': 'Starbucks',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '565f2ab1498e815382fad18d',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 569,
#    'geocodes': {'main': {'latitude': 49.26228, 'longitude': -123.122284},
#     'roof': {'latitude': 49.26228, 'longitude': -123.122284}},
#    'link': '/v3/places/565f2ab1498e815382fad18d',
#    'location': {'address': '820 10th Ave W',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '820 10th Ave W, Vancouver BC V5Z 1M9',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 1M9',
#     'region': 'BC'},
#    'name': 'Bean Around the World',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '56b3a15b498ef1bb0170b886',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13334,
#      'name': 'Sandwich Spot',
#      'short_name': 'Sandwich Spot',
#      'plural_name': 'Sandwich Spots',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 571,
#    'geocodes': {'main': {'latitude': 49.263201, 'longitude': -123.122201},
#     'roof': {'latitude': 49.263201, 'longitude': -123.122201}},
#    'link': '/v3/places/56b3a15b498ef1bb0170b886',
#    'location': {'address': '802 Broadway W',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '802 Broadway W, Vancouver BC V5Z 1J8',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 1J8',
#     'region': 'BC'},
#    'name': "Chef's Harvest",
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4bdc66ab3904a59393014e9e',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 578,
#    'geocodes': {'main': {'latitude': 49.263613, 'longitude': -123.122074},
#     'roof': {'latitude': 49.263613, 'longitude': -123.122074}},
#    'link': '/v3/places/4bdc66ab3904a59393014e9e',
#    'location': {'address': '805 Broadway W',
#     'address_extended': '# 111',
#     'country': 'CA',
#     'cross_street': 'Willow',
#     'formatted_address': '805 Broadway W (Willow), Vancouver BC V5Z 1K1',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 1K1',
#     'region': 'BC'},
#    'name': "Tony's Coffee",
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '2cc013b21b1c4dfb599e7061',
#    'categories': [{'id': 13036,
#      'name': 'Tea Room',
#      'short_name': 'Tea Room',
#      'plural_name': 'Tea Rooms',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 605,
#    'geocodes': {'drop_off': {'latitude': 49.262102, 'longitude': -123.106104},
#     'main': {'latitude': 49.261859, 'longitude': -123.106109},
#     'roof': {'latitude': 49.261859, 'longitude': -123.106109}},
#    'link': '/v3/places/2cc013b21b1c4dfb599e7061',
#    'location': {'address': '46 10th Ave W',
#     'country': 'CA',
#     'formatted_address': '46 10th Ave W, Vancouver BC V5Y 1R6',
#     'locality': 'Vancouver',
#     'postcode': 'V5Y 1R6',
#     'region': 'BC'},
#    'name': 'Tea Sparrow',
#    'related_places': {}},
#   {'fsq_id': '5898f8a5af5c1411a1a2263d',
#    'categories': [{'id': 13032,
#      'name': 'Cafe, Coffee, and Tea House',
#      'short_name': 'Cafe, Coffee, and Tea House',
#      'plural_name': 'Cafes, Coffee, and Tea Houses',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'd5719cc0-d890-0132-61d3-7a163eb2a6fc',
#      'name': 'Tim Hortons'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 676,
#    'geocodes': {'main': {'latitude': 49.265791, 'longitude': -123.122584},
#     'roof': {'latitude': 49.265791, 'longitude': -123.122584}},
#    'link': '/v3/places/5898f8a5af5c1411a1a2263d',
#    'location': {'address': '818 6th Ave W',
#     'country': 'CA',
#     'cross_street': 'Willow Street',
#     'formatted_address': '818 6th Ave W (Willow Street), Vancouver BC V5Z 1A6',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 1A6',
#     'region': 'BC'},
#    'name': 'Tim Hortons',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '5478ca03498e3bbc45e6ce54',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 724,
#    'geocodes': {'drop_off': {'latitude': 49.264523, 'longitude': -123.104835},
#     'main': {'latitude': 49.264531, 'longitude': -123.105038},
#     'roof': {'latitude': 49.264531, 'longitude': -123.105038}},
#    'link': '/v3/places/5478ca03498e3bbc45e6ce54',
#    'location': {'address': '2301 Ontario St',
#     'country': 'CA',
#     'cross_street': 'at 7th Ave',
#     'formatted_address': '2301 Ontario St (at 7th Ave), Vancouver BC V5T 2X5',
#     'locality': 'Vancouver',
#     'postcode': 'V5T 2X5',
#     'region': 'BC'},
#    'name': 'Elysian Coffee',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4b0b9b4af964a5208e3223e3',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'Unsure',
#    'distance': 727,
#    'geocodes': {'drop_off': {'latitude': 49.257715, 'longitude': -123.12131},
#     'main': {'latitude': 49.257548, 'longitude': -123.121313},
#     'roof': {'latitude': 49.257548, 'longitude': -123.121313}},
#    'link': '/v3/places/4b0b9b4af964a5208e3223e3',
#    'location': {'address': '600 W 17th Ave',
#     'country': 'CA',
#     'cross_street': 'Ash Street',
#     'formatted_address': '600 W 17th Ave (Ash Street), Vancouver BC V5Z 1T7',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 1T7',
#     'region': 'BC'},
#    'name': 'CoffeeGeek Lab',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4b99694ef964a5208e7935e3',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 733,
#    'geocodes': {'main': {'latitude': 49.260643, 'longitude': -123.124172},
#     'roof': {'latitude': 49.260643, 'longitude': -123.124172}},
#    'link': '/v3/places/4b99694ef964a5208e7935e3',
#    'location': {'address': '899 12th Ave W',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '899 12th Ave W, Vancouver BC V5Z 1M9',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 1M9',
#     'region': 'BC'},
#    'name': 'Cafe Ami',
#    'related_places': {'parent': {'fsq_id': '4acd6f21f964a52017cc20e3',
#      'categories': [{'id': 15014,
#        'name': 'Hospital',
#        'short_name': 'Hospital',
#        'plural_name': 'Hospitals',
#        'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#         'suffix': '.png'}}],
#      'name': 'Vancouver General Hospital'}},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '5c26bb39b8fd9d002cf9ad2d',
#    'categories': [{'id': 13033,
#      'name': 'Bubble Tea Shop',
#      'short_name': 'Bubble Tea',
#      'plural_name': 'Bubble Tea Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#       'suffix': '.png'}},
#     {'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 755,
#    'geocodes': {'drop_off': {'latitude': 49.255629, 'longitude': -123.115138},
#     'main': {'latitude': 49.25562, 'longitude': -123.114904},
#     'roof': {'latitude': 49.25562, 'longitude': -123.114904}},
#    'link': '/v3/places/5c26bb39b8fd9d002cf9ad2d',
#    'location': {'address': '3306 Cambie St',
#     'country': 'CA',
#     'cross_street': 'W 17th Avenue',
#     'formatted_address': '3306 Cambie St (W 17th Avenue), Vancouver BC V5Z 2W5',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 2W5',
#     'region': 'BC'},
#    'name': 'Hot Cha Cafe',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '5efabc12fca34c0008135446',
#    'categories': [{'id': 13033,
#      'name': 'Bubble Tea Shop',
#      'short_name': 'Bubble Tea',
#      'plural_name': 'Bubble Tea Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 759,
#    'geocodes': {'drop_off': {'latitude': 49.255629, 'longitude': -123.115138},
#     'main': {'latitude': 49.25562, 'longitude': -123.114904},
#     'roof': {'latitude': 49.25562, 'longitude': -123.114904}},
#    'link': '/v3/places/5efabc12fca34c0008135446',
#    'location': {'address': '3318 Cambie St',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '3318 Cambie St, Vancouver BC V5Z 2W5',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 2W5',
#     'region': 'BC'},
#    'name': 'Ben Gong’s Tea',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4c48639e417b20a19bbfe0a9',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13049,
#      'name': 'Diner',
#      'short_name': 'Diner',
#      'plural_name': 'Diners',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 771,
#    'geocodes': {'main': {'latitude': 49.267528, 'longitude': -123.106835},
#     'roof': {'latitude': 49.267528, 'longitude': -123.106835}},
#    'link': '/v3/places/4c48639e417b20a19bbfe0a9',
#    'location': {'address': '1945 Manitoba St',
#     'country': 'CA',
#     'cross_street': 'at 4th Ave.',
#     'formatted_address': '1945 Manitoba St (at 4th Ave.), Vancouver BC V5Y 3A1',
#     'locality': 'Vancouver',
#     'postcode': 'V5Y 3A1',
#     'region': 'BC'},
#    'name': "Laura's Coffee Shop",
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '5cf2f1820e3239002b2c5bd2',
#    'categories': [{'id': 13036,
#      'name': 'Tea Room',
#      'short_name': 'Tea Room',
#      'plural_name': 'Tea Rooms',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 779,
#    'geocodes': {'drop_off': {'latitude': 49.255414, 'longitude': -123.115145},
#     'main': {'latitude': 49.255425, 'longitude': -123.115455},
#     'roof': {'latitude': 49.255425, 'longitude': -123.115455}},
#    'link': '/v3/places/5cf2f1820e3239002b2c5bd2',
#    'location': {'address': '3361 Cambie St',
#     'country': 'CA',
#     'cross_street': 'W 18th Ave',
#     'formatted_address': '3361 Cambie St (W 18th Ave), Vancouver BC V5Z 2W6',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 2W6',
#     'region': 'BC'},
#    'name': 'Paragon Tea Room',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4db27d8d5da3944066b913af',
#    'categories': [{'id': 11003,
#      'name': 'Architecture Firm',
#      'short_name': 'Architecture Firm',
#      'plural_name': 'Architecture Firms',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'}},
#     {'id': 11092,
#      'name': 'Landscaper and Gardener',
#      'short_name': 'Landscaper and Gardener',
#      'plural_name': 'Landscaper and Gardeners',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#       'suffix': '.png'}},
#     {'id': 13036,
#      'name': 'Tea Room',
#      'short_name': 'Tea Room',
#      'plural_name': 'Tea Rooms',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 799,
#    'geocodes': {'main': {'latitude': 49.262275, 'longitude': -123.103549},
#     'roof': {'latitude': 49.262275, 'longitude': -123.103549}},
#    'link': '/v3/places/4db27d8d5da3944066b913af',
#    'location': {'address': '2525 Quebec',
#     'country': 'CA',
#     'cross_street': '10th',
#     'formatted_address': '2525 Quebec (10th), Vancouver BC V6B 3P7',
#     'locality': 'Vancouver',
#     'postcode': 'V6B 3P7',
#     'region': 'BC'},
#    'name': 'Cornerstone Landscape and Construction Group',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '53c4959b498ebad0cc0cdfb4',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13039,
#      'name': 'Deli',
#      'short_name': 'Deli',
#      'plural_name': 'Delis',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 812,
#    'geocodes': {'drop_off': {'latitude': 49.261904, 'longitude': -123.103014},
#     'main': {'latitude': 49.261909, 'longitude': -123.103193},
#     'roof': {'latitude': 49.261909, 'longitude': -123.103193}},
#    'link': '/v3/places/53c4959b498ebad0cc0cdfb4',
#    'location': {'address': '2601 Quebec St',
#     'country': 'CA',
#     'cross_street': 'E 10th Ave',
#     'formatted_address': '2601 Quebec St (E 10th Ave), Vancouver BC V5T 3A6',
#     'locality': 'Vancouver',
#     'postcode': 'V5T 3A6',
#     'region': 'BC'},
#    'name': 'The Federal Store',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '5056550be4b04df235227f2d',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 812,
#    'geocodes': {'drop_off': {'latitude': 49.257026, 'longitude': -123.121853},
#     'main': {'latitude': 49.257182, 'longitude': -123.12185},
#     'roof': {'latitude': 49.257182, 'longitude': -123.12185}},
#    'link': '/v3/places/5056550be4b04df235227f2d',
#    'location': {'address': '797 16th Ave W',
#     'country': 'CA',
#     'cross_street': 'at Willow St',
#     'formatted_address': '797 16th Ave W (at Willow St), Vancouver BC V5Z 1S8',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 1S8',
#     'region': 'BC'},
#    'name': 'Willow Cafe Bakery',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '54f4986f498e31ed2e9c12ad',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 816,
#    'geocodes': {'drop_off': {'latitude': 49.255058, 'longitude': -123.115157},
#     'main': {'latitude': 49.255064, 'longitude': -123.115343},
#     'roof': {'latitude': 49.255064, 'longitude': -123.115343}},
#    'link': '/v3/places/54f4986f498e31ed2e9c12ad',
#    'location': {'address': '3399 Cambie St',
#     'country': 'CA',
#     'cross_street': '18th Ave',
#     'formatted_address': '3399 Cambie St (18th Ave), Vancouver BC V5Z 2W6',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 2W6',
#     'region': 'BC'},
#    'name': 'JJ Bean Coffee Roasters',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4aaac19ef964a5203a5720e3',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'ab4c54c0-d68a-012e-5619-003048cad9da',
#      'name': 'Starbucks'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 840,
#    'geocodes': {'main': {'latitude': 49.260787, 'longitude': -123.125644},
#     'roof': {'latitude': 49.260787, 'longitude': -123.125644}},
#    'link': '/v3/places/4aaac19ef964a5203a5720e3',
#    'location': {'address': '2787 Laurel St',
#     'address_extended': 'Academic Ambulatory Care Centre',
#     'country': 'CA',
#     'cross_street': 'at W 12th Ave',
#     'formatted_address': '2787 Laurel St (at W 12th Ave), Vancouver BC V5Z 0A8',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 0A8',
#     'region': 'BC'},
#    'name': 'Starbucks',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '5c82ee25cbcdee002c576be6',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 873,
#    'geocodes': {'main': {'latitude': 49.263171, 'longitude': -123.126091},
#     'roof': {'latitude': 49.263171, 'longitude': -123.126091}},
#    'link': '/v3/places/5c82ee25cbcdee002c576be6',
#    'location': {'address': '992 West Broadway',
#     'country': 'CA',
#     'cross_street': 'Oak Street',
#     'formatted_address': '992 West Broadway (Oak Street), Vancouver BC V5Z 1K7',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 1K7',
#     'region': 'BC'},
#    'name': 'Dalina',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '508eda05e4b0e43936144601',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13039,
#      'name': 'Deli',
#      'short_name': 'Deli',
#      'plural_name': 'Delis',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 932,
#    'geocodes': {'drop_off': {'latitude': 49.25476, 'longitude': -123.109539},
#     'main': {'latitude': 49.254563, 'longitude': -123.109543},
#     'roof': {'latitude': 49.254563, 'longitude': -123.109543}},
#    'link': '/v3/places/508eda05e4b0e43936144601',
#    'location': {'address': '198 18th Ave W',
#     'country': 'CA',
#     'cross_street': 'at Columbia St',
#     'formatted_address': '198 18th Ave W (at Columbia St), Vancouver BC V5Y 2A5',
#     'locality': 'Vancouver',
#     'postcode': 'V5Y 2A5',
#     'region': 'BC'},
#    'name': 'The Mighty Oak',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '538ccfce498ecd4ebc0df664',
#    'categories': [{'id': 13032,
#      'name': 'Cafe, Coffee, and Tea House',
#      'short_name': 'Cafe, Coffee, and Tea House',
#      'plural_name': 'Cafes, Coffee, and Tea Houses',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13134,
#      'name': 'Comfort Food Restaurant',
#      'short_name': 'Comfort Food',
#      'plural_name': 'Comfort Food Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}},
#     {'id': 13334,
#      'name': 'Sandwich Spot',
#      'short_name': 'Sandwich Spot',
#      'plural_name': 'Sandwich Spots',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 933,
#    'geocodes': {'drop_off': {'latitude': 49.261122, 'longitude': -123.10206},
#     'main': {'latitude': 49.261018, 'longitude': -123.102063},
#     'roof': {'latitude': 49.261018, 'longitude': -123.102063}},
#    'link': '/v3/places/538ccfce498ecd4ebc0df664',
#    'location': {'address': '152 11th Ave E',
#     'country': 'CA',
#     'cross_street': 'btwn Main & Quebec',
#     'formatted_address': '152 11th Ave E (btwn Main & Quebec), Vancouver BC V5T 2C2',
#     'locality': 'Vancouver',
#     'postcode': 'V5T 2C2',
#     'region': 'BC'},
#    'name': 'Dock Lunch',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4ab793e7f964a520227a20e3',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [{'id': 'ab4c54c0-d68a-012e-5619-003048cad9da',
#      'name': 'Starbucks'}],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 934,
#    'geocodes': {'main': {'latitude': 49.254096, 'longitude': -123.115018},
#     'roof': {'latitude': 49.254096, 'longitude': -123.115018}},
#    'link': '/v3/places/4ab793e7f964a520227a20e3',
#    'location': {'address': '3492 Cambie St',
#     'country': 'CA',
#     'cross_street': 'at 19th Ave.',
#     'formatted_address': '3492 Cambie St (at 19th Ave.), Vancouver BC V5Z 2W8',
#     'locality': 'Vancouver',
#     'postcode': 'V5Z 2W8',
#     'region': 'BC'},
#    'name': 'Starbucks',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '523871de11d2c5fc2ec832a1',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 936,
#    'geocodes': {'drop_off': {'latitude': 49.270248, 'longitude': -123.109},
#     'main': {'latitude': 49.270118, 'longitude': -123.109002},
#     'roof': {'latitude': 49.270118, 'longitude': -123.109002}},
#    'link': '/v3/places/523871de11d2c5fc2ec832a1',
#    'location': {'address': '188 1st Ave W',
#     'address_extended': '# 104',
#     'country': 'CA',
#     'cross_street': 'at Columbia St',
#     'formatted_address': '188 1st Ave W (at Columbia St), Vancouver BC V5Y 1A4',
#     'locality': 'Vancouver',
#     'postcode': 'V5Y 1A4',
#     'region': 'BC'},
#    'name': 'JJ Bean Coffee Roasters',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '51f0591a498e26b88854db2f',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 964,
#    'geocodes': {'drop_off': {'latitude': 49.26927, 'longitude': -123.106354},
#     'main': {'latitude': 49.269458, 'longitude': -123.10635},
#     'roof': {'latitude': 49.269458, 'longitude': -123.10635}},
#    'link': '/v3/places/51f0591a498e26b88854db2f',
#    'location': {'address': '97 2nd Ave W',
#     'country': 'CA',
#     'cross_street': 'West 2nd Avenue At Manitoba Street',
#     'formatted_address': '97 2nd Ave W (West 2nd Avenue At Manitoba Street), Vancouver BC V5Y 1B1',
#     'locality': 'Vancouver',
#     'postcode': 'V5Y 1B1',
#     'region': 'BC'},
#    'name': 'Blenz Coffee',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '5dffcf02e6be4c00082e32dd',
#    'categories': [{'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 965,
#    'geocodes': {'drop_off': {'latitude': 49.270624, 'longitude': -123.109399},
#     'main': {'latitude': 49.270612, 'longitude': -123.109206},
#     'roof': {'latitude': 49.270612, 'longitude': -123.109206}},
#    'link': '/v3/places/5dffcf02e6be4c00082e32dd',
#    'location': {'address': '1778 Columbia St',
#     'country': 'CA',
#     'cross_street': 'W 2nd Ave',
#     'formatted_address': '1778 Columbia St (W 2nd Ave), Vancouver BC V5Y 1B8',
#     'locality': 'Vancouver',
#     'postcode': 'V5Y 1B8',
#     'region': 'BC'},
#    'name': 'The Press Room',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4aa6f149f964a520914b20e3',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13035,
#      'name': 'Coffee Shop',
#      'short_name': 'Coffee Shop',
#      'plural_name': 'Coffee Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'}},
#     {'id': 13065,
#      'name': 'Restaurant',
#      'short_name': 'Restaurant',
#      'plural_name': 'Restaurants',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 977,
#    'geocodes': {'main': {'latitude': 49.262496, 'longitude': -123.100647},
#     'roof': {'latitude': 49.262496, 'longitude': -123.100647}},
#    'link': '/v3/places/4aa6f149f964a520914b20e3',
#    'location': {'address': '2528 Main St',
#     'country': 'CA',
#     'cross_street': 'at East Broadway',
#     'formatted_address': '2528 Main St (at East Broadway), Vancouver BC V5T 3E4',
#     'locality': 'Vancouver',
#     'postcode': 'V5T 3E4',
#     'region': 'BC'},
#    'name': 'Bean Around the World',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '4aae6272f964a520f06120e3',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13049,
#      'name': 'Diner',
#      'short_name': 'Diner',
#      'plural_name': 'Diners',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 984,
#    'geocodes': {'main': {'latitude': 49.268608, 'longitude': -123.104493},
#     'roof': {'latitude': 49.268608, 'longitude': -123.104493}},
#    'link': '/v3/places/4aae6272f964a520f06120e3',
#    'location': {'address': '1836 Ontario St',
#     'country': 'CA',
#     'cross_street': 'at 3rd Ave.',
#     'formatted_address': '1836 Ontario St (at 3rd Ave.), Vancouver BC V5T 2W6',
#     'locality': 'Vancouver',
#     'postcode': 'V5T 2W6',
#     'region': 'BC'},
#    'name': 'Argo Cafe',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '5b902967a0215b002cf659fa',
#    'categories': [{'id': 13033,
#      'name': 'Bubble Tea Shop',
#      'short_name': 'Bubble Tea',
#      'plural_name': 'Bubble Tea Shops',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'VeryLikelyOpen',
#    'distance': 994,
#    'geocodes': {'drop_off': {'latitude': 49.269624, 'longitude': -123.106557},
#     'main': {'latitude': 49.269608, 'longitude': -123.106282},
#     'roof': {'latitude': 49.269608, 'longitude': -123.106282}},
#    'link': '/v3/places/5b902967a0215b002cf659fa',
#    'location': {'address': '1764 Manitoba St',
#     'country': 'CA',
#     'cross_street': '',
#     'formatted_address': '1764 Manitoba St, Vancouver BC V5Y 0H1',
#     'locality': 'Vancouver',
#     'postcode': 'V5Y 0H1',
#     'region': 'BC'},
#    'name': 'The Bubble Tea Shop',
#    'related_places': {},
#    'timezone': 'America/Vancouver'},
#   {'fsq_id': '59836ba9f5e9d71716a6931a',
#    'categories': [{'id': 13034,
#      'name': 'Café',
#      'short_name': 'Café',
#      'plural_name': 'Cafés',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'}},
#     {'id': 13036,
#      'name': 'Tea Room',
#      'short_name': 'Tea Room',
#      'plural_name': 'Tea Rooms',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 1001,
#    'geocodes': {'main': {'latitude': 49.268598, 'longitude': -123.104898},
#     'roof': {'latitude': 49.268598, 'longitude': -123.104898}},
#    'link': '/v3/places/59836ba9f5e9d71716a6931a',
#    'location': {'address': '1863 Ontario St',
#     'country': 'CA',
#     'cross_street': '3rd ave',
#     'formatted_address': '1863 Ontario St (3rd ave), Vancouver BC V5T 0C9',
#     'locality': 'Vancouver',
#     'postcode': 'V5T 0C9',
#     'region': 'BC'},
#    'name': 'Oddity Kombucha',
#    'related_places': {},
#    'timezone': 'America/Vancouver'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 49.262487,
#      'longitude': -123.114397},
#     'radius': 1000}}}}

# %%
# Categories - 6 API calls for each station_id (each of these strings for 'categories=' in the query parameter)
# Unlike Yelp, this needs a dictionary because the category_ids are numerical and hard for humans to identify easily when looking at the eventual dataframe
categories_dict = {
    '10027,10047,10059,10069' : 'Arts and Entertainment: Museum|Public Art',
    '13032' : 'Dining and Drinking: Cafe, Coffee and Tea House',
    '16003,16020,16046' : 'Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout',
    '16004' : 'Bike Trail',
    '16032' : 'Park',
    '19010,19013,19014,19019' : 'Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental'
}

# Set Default Radius
radius = 1000

# Load the citybikes dataframe
stations_df = pd.read_csv('../data/citybikes_vancouver.csv')

# Generate the list of station_ids
station_ids_list = stations_df['id'].tolist()
station_ids_list = sorted(station_ids_list)

# Set up an empty dataframe 'rolling_df' which will collect each individual API call into the larger dataframe
rolling_df = pd.DataFrame()

#for station_id in station_ids_list[:1]:  # Testing only
for station_id in station_ids_list:
    print(f"************** New Station! **************")
    for entry_category, category_text in categories_dict.items():
        filt_station = (stations_df['id'] == station_id)
        station_lat = stations_df.loc[filt_station]['lat'].values[0]
        station_long = stations_df.loc[filt_station]['long'].values[0]
        print (f"Working on station_id: {station_id}, categories being sent is: {entry_category} ({category_text})")
        print (f"     station_lat, station_long = ({station_lat}, {station_long})")

        # Call the function to do Foursquare GET request from the API
        payload_dict = foursquare_get_request_place_search(station_lat, station_long, radius, entry_category, FOURSQUARE_KEY)
        
        # Define/reset the fsqdict dictionary, which holds the parsed JSON from the REST GET API call
        fsqdict = dict()
        create_default_fsqdict(fsqdict)

        # Parse the JSON from the payload from the API call
        fsqdict_from_response(station_id, fsqdict, payload_dict, entry_category, category_text)
        
        # Create a temp_df dataframe
        temp_df = pd.DataFrame(fsqdict)

        # Debug
        print(f"          number rows = {temp_df.shape[0]}")

        # Add the just-generated dataframe from this singular previous API call, to the cumulative "rolling_df" dataframe for the entirety of the station_ids
        rolling_df = pd.concat([rolling_df, temp_df], ignore_index=True)
# Out:
# ************** New Station! **************
# Working on station_id: 00fa94ad698dc4a9e4d708d6fd32f294, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.291909, -123.140713)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.291909,-123.140713&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 3
# Working on station_id: 00fa94ad698dc4a9e4d708d6fd32f294, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.291909, -123.140713)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.291909,-123.140713&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 32
# Working on station_id: 00fa94ad698dc4a9e4d708d6fd32f294, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.291909, -123.140713)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.291909,-123.140713&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 5
# Working on station_id: 00fa94ad698dc4a9e4d708d6fd32f294, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.291909, -123.140713)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.291909,-123.140713&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 00fa94ad698dc4a9e4d708d6fd32f294, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.291909, -123.140713)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.291909,-123.140713&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 27
# Working on station_id: 00fa94ad698dc4a9e4d708d6fd32f294, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.291909, -123.140713)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.291909,-123.140713&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 30
# ************** New Station! **************
# Working on station_id: 012d3e06901cc222b1c2cf0a2ace3a29, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.262321, -123.09306)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.262321,-123.09306&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 1
# Working on station_id: 012d3e06901cc222b1c2cf0a2ace3a29, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.262321, -123.09306)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.262321,-123.09306&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 36
# Working on station_id: 012d3e06901cc222b1c2cf0a2ace3a29, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.262321, -123.09306)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.262321,-123.09306&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 012d3e06901cc222b1c2cf0a2ace3a29, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.262321, -123.09306)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.262321,-123.09306&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 012d3e06901cc222b1c2cf0a2ace3a29, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.262321, -123.09306)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.262321,-123.09306&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 14
# Working on station_id: 012d3e06901cc222b1c2cf0a2ace3a29, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.262321, -123.09306)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.262321,-123.09306&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 7
# ************** New Station! **************
# Working on station_id: 029a505bd4422a1afd127987757f71a6, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.275882, -123.071865)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.275882,-123.071865&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 029a505bd4422a1afd127987757f71a6, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.275882, -123.071865)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.275882,-123.071865&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 35
# Working on station_id: 029a505bd4422a1afd127987757f71a6, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.275882, -123.071865)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.275882,-123.071865&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 029a505bd4422a1afd127987757f71a6, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.275882, -123.071865)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.275882,-123.071865&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 029a505bd4422a1afd127987757f71a6, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.275882, -123.071865)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.275882,-123.071865&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 12
# Working on station_id: 029a505bd4422a1afd127987757f71a6, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.275882, -123.071865)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.275882,-123.071865&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 5
# ************** New Station! **************
# Working on station_id: 0438114d2e6b96118de69bc9775bb21e, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.28803, -123.142135)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.28803,-123.142135&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 2
# Working on station_id: 0438114d2e6b96118de69bc9775bb21e, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.28803, -123.142135)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.28803,-123.142135&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 33
# Working on station_id: 0438114d2e6b96118de69bc9775bb21e, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.28803, -123.142135)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.28803,-123.142135&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0438114d2e6b96118de69bc9775bb21e, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.28803, -123.142135)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.28803,-123.142135&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0438114d2e6b96118de69bc9775bb21e, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.28803, -123.142135)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.28803,-123.142135&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 24
# Working on station_id: 0438114d2e6b96118de69bc9775bb21e, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.28803, -123.142135)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.28803,-123.142135&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 29
# ************** New Station! **************
# Working on station_id: 0459b7e93703980b853cd65a9dc60596, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.273777, -123.092723)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.273777,-123.092723&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 9
# Working on station_id: 0459b7e93703980b853cd65a9dc60596, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.273777, -123.092723)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.273777,-123.092723&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 42
# Working on station_id: 0459b7e93703980b853cd65a9dc60596, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.273777, -123.092723)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.273777,-123.092723&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 1
# Working on station_id: 0459b7e93703980b853cd65a9dc60596, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.273777, -123.092723)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.273777,-123.092723&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0459b7e93703980b853cd65a9dc60596, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.273777, -123.092723)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.273777,-123.092723&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 18
# Working on station_id: 0459b7e93703980b853cd65a9dc60596, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.273777, -123.092723)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.273777,-123.092723&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 9
# ************** New Station! **************
# Working on station_id: 04f64fde5ba1ebde8ad78c74914adb34, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.259469, -123.145718)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.259469,-123.145718&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 2
# Working on station_id: 04f64fde5ba1ebde8ad78c74914adb34, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.259469, -123.145718)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.259469,-123.145718&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 34
# Working on station_id: 04f64fde5ba1ebde8ad78c74914adb34, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.259469, -123.145718)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.259469,-123.145718&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 04f64fde5ba1ebde8ad78c74914adb34, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.259469, -123.145718)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.259469,-123.145718&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 04f64fde5ba1ebde8ad78c74914adb34, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.259469, -123.145718)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.259469,-123.145718&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 15
# Working on station_id: 04f64fde5ba1ebde8ad78c74914adb34, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.259469, -123.145718)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.259469,-123.145718&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 6
# ************** New Station! **************
# Working on station_id: 06487275cd19694152824c7c3088e8ff, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.266314, -123.116011)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.266314,-123.116011&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 4
# Working on station_id: 06487275cd19694152824c7c3088e8ff, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.266314, -123.116011)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.266314,-123.116011&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 40
# Working on station_id: 06487275cd19694152824c7c3088e8ff, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.266314, -123.116011)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.266314,-123.116011&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 1
# Working on station_id: 06487275cd19694152824c7c3088e8ff, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.266314, -123.116011)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.266314,-123.116011&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 06487275cd19694152824c7c3088e8ff, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.266314, -123.116011)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.266314,-123.116011&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 22
# Working on station_id: 06487275cd19694152824c7c3088e8ff, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.266314, -123.116011)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.266314,-123.116011&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 12
# ************** New Station! **************
# Working on station_id: 064a7b39b1dbc4bfc4cf8f454e360c57, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.264928, -123.168068)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.264928,-123.168068&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 064a7b39b1dbc4bfc4cf8f454e360c57, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.264928, -123.168068)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.264928,-123.168068&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 27
# Working on station_id: 064a7b39b1dbc4bfc4cf8f454e360c57, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.264928, -123.168068)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.264928,-123.168068&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 1
# Working on station_id: 064a7b39b1dbc4bfc4cf8f454e360c57, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.264928, -123.168068)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.264928,-123.168068&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 064a7b39b1dbc4bfc4cf8f454e360c57, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.264928, -123.168068)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.264928,-123.168068&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 14
# Working on station_id: 064a7b39b1dbc4bfc4cf8f454e360c57, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.264928, -123.168068)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.264928,-123.168068&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 5
# ************** New Station! **************
# Working on station_id: 066ecc3584913fa035ec1417323beb80, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.243375, -123.104978)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.243375,-123.104978&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 1
# Working on station_id: 066ecc3584913fa035ec1417323beb80, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.243375, -123.104978)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.243375,-123.104978&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 16
# Working on station_id: 066ecc3584913fa035ec1417323beb80, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.243375, -123.104978)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.243375,-123.104978&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 066ecc3584913fa035ec1417323beb80, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.243375, -123.104978)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.243375,-123.104978&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 066ecc3584913fa035ec1417323beb80, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.243375, -123.104978)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.243375,-123.104978&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 18
# Working on station_id: 066ecc3584913fa035ec1417323beb80, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.243375, -123.104978)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.243375,-123.104978&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 1
# ************** New Station! **************
# Working on station_id: 06bdc4d55f34b2a491305534fd5defda, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.283968, -123.061615)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.283968,-123.061615&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 06bdc4d55f34b2a491305534fd5defda, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.283968, -123.061615)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.283968,-123.061615&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 20
# Working on station_id: 06bdc4d55f34b2a491305534fd5defda, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.283968, -123.061615)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.283968,-123.061615&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 2
# Working on station_id: 06bdc4d55f34b2a491305534fd5defda, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.283968, -123.061615)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.283968,-123.061615&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 06bdc4d55f34b2a491305534fd5defda, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.283968, -123.061615)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.283968,-123.061615&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 6
# Working on station_id: 06bdc4d55f34b2a491305534fd5defda, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.283968, -123.061615)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.283968,-123.061615&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 4
# ************** New Station! **************
# Working on station_id: 07b13214cb69f2ec007d888450f3d6bc, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.259579, -123.114769)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.259579,-123.114769&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 2
# Working on station_id: 07b13214cb69f2ec007d888450f3d6bc, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.259579, -123.114769)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.259579,-123.114769&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 40
# Working on station_id: 07b13214cb69f2ec007d888450f3d6bc, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.259579, -123.114769)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.259579,-123.114769&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 07b13214cb69f2ec007d888450f3d6bc, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.259579, -123.114769)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.259579,-123.114769&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 1
# Working on station_id: 07b13214cb69f2ec007d888450f3d6bc, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.259579, -123.114769)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.259579,-123.114769&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 16
# Working on station_id: 07b13214cb69f2ec007d888450f3d6bc, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.259579, -123.114769)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.259579,-123.114769&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 10
# ************** New Station! **************
# Working on station_id: 085a0e120a08a80a58c0ae0ff9da565a, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.247854, -123.153422)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.247854,-123.153422&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 085a0e120a08a80a58c0ae0ff9da565a, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.247854, -123.153422)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.247854,-123.153422&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 1
# Working on station_id: 085a0e120a08a80a58c0ae0ff9da565a, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.247854, -123.153422)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.247854,-123.153422&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 085a0e120a08a80a58c0ae0ff9da565a, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.247854, -123.153422)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.247854,-123.153422&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 085a0e120a08a80a58c0ae0ff9da565a, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.247854, -123.153422)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.247854,-123.153422&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 3
# Working on station_id: 085a0e120a08a80a58c0ae0ff9da565a, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.247854, -123.153422)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.247854,-123.153422&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 1
# ************** New Station! **************
# Working on station_id: 08c7a90bf297fde8c1f1156db13987d4, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.257939, -123.089531)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.257939,-123.089531&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 2
# Working on station_id: 08c7a90bf297fde8c1f1156db13987d4, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.257939, -123.089531)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.257939,-123.089531&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 26
# Working on station_id: 08c7a90bf297fde8c1f1156db13987d4, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.257939, -123.089531)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.257939,-123.089531&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 08c7a90bf297fde8c1f1156db13987d4, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.257939, -123.089531)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.257939,-123.089531&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 08c7a90bf297fde8c1f1156db13987d4, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.257939, -123.089531)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.257939,-123.089531&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 17
# Working on station_id: 08c7a90bf297fde8c1f1156db13987d4, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.257939, -123.089531)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.257939,-123.089531&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 5
# ************** New Station! **************
# Working on station_id: 0a43242bee10cd33f539af2c1bf5ecbf, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.256857, -123.065646)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.256857,-123.065646&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0a43242bee10cd33f539af2c1bf5ecbf, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.256857, -123.065646)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.256857,-123.065646&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 8
# Working on station_id: 0a43242bee10cd33f539af2c1bf5ecbf, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.256857, -123.065646)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.256857,-123.065646&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 1
# Working on station_id: 0a43242bee10cd33f539af2c1bf5ecbf, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.256857, -123.065646)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.256857,-123.065646&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0a43242bee10cd33f539af2c1bf5ecbf, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.256857, -123.065646)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.256857,-123.065646&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 9
# Working on station_id: 0a43242bee10cd33f539af2c1bf5ecbf, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.256857, -123.065646)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.256857,-123.065646&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 1
# ************** New Station! **************
# Working on station_id: 0b543fc4e694fe07a54dac48bb1b3390, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.282758, -123.122092)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.282758,-123.122092&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 12
# Working on station_id: 0b543fc4e694fe07a54dac48bb1b3390, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.282758, -123.122092)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.282758,-123.122092&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0b543fc4e694fe07a54dac48bb1b3390, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.282758, -123.122092)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.282758,-123.122092&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 3
# Working on station_id: 0b543fc4e694fe07a54dac48bb1b3390, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.282758, -123.122092)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.282758,-123.122092&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0b543fc4e694fe07a54dac48bb1b3390, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.282758, -123.122092)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.282758,-123.122092&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0b543fc4e694fe07a54dac48bb1b3390, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.282758, -123.122092)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.282758,-123.122092&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 0
# ************** New Station! **************
# Working on station_id: 0c42f45e4a14957ad4a6d521d0ba8bc3, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.289255, -123.132677)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.289255,-123.132677&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 3
# Working on station_id: 0c42f45e4a14957ad4a6d521d0ba8bc3, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.289255, -123.132677)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.289255,-123.132677&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 45
# Working on station_id: 0c42f45e4a14957ad4a6d521d0ba8bc3, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.289255, -123.132677)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.289255,-123.132677&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 5
# Working on station_id: 0c42f45e4a14957ad4a6d521d0ba8bc3, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.289255, -123.132677)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.289255,-123.132677&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0c42f45e4a14957ad4a6d521d0ba8bc3, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.289255, -123.132677)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.289255,-123.132677&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 27
# Working on station_id: 0c42f45e4a14957ad4a6d521d0ba8bc3, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.289255, -123.132677)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.289255,-123.132677&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 50
# ************** New Station! **************
# Working on station_id: 0c9ad3e3703e5869b82619ecdf54f43e, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.2685027, -123.0975014)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.2685027,-123.0975014&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 8
# Working on station_id: 0c9ad3e3703e5869b82619ecdf54f43e, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.2685027, -123.0975014)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.2685027,-123.0975014&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 43
# Working on station_id: 0c9ad3e3703e5869b82619ecdf54f43e, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.2685027, -123.0975014)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.2685027,-123.0975014&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0c9ad3e3703e5869b82619ecdf54f43e, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.2685027, -123.0975014)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.2685027,-123.0975014&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0c9ad3e3703e5869b82619ecdf54f43e, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.2685027, -123.0975014)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.2685027,-123.0975014&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 21
# Working on station_id: 0c9ad3e3703e5869b82619ecdf54f43e, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.2685027, -123.0975014)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.2685027,-123.0975014&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 6
# ************** New Station! **************
# Working on station_id: 0cee06d7d10f7d3162cea03d22b7beed, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.26151, -123.089413)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.26151,-123.089413&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 1
# Working on station_id: 0cee06d7d10f7d3162cea03d22b7beed, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.26151, -123.089413)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.26151,-123.089413&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 29
# Working on station_id: 0cee06d7d10f7d3162cea03d22b7beed, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.26151, -123.089413)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.26151,-123.089413&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0cee06d7d10f7d3162cea03d22b7beed, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.26151, -123.089413)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.26151,-123.089413&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0cee06d7d10f7d3162cea03d22b7beed, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.26151, -123.089413)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.26151,-123.089413&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 16
# Working on station_id: 0cee06d7d10f7d3162cea03d22b7beed, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.26151, -123.089413)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.26151,-123.089413&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 5
# ************** New Station! **************
# Working on station_id: 0cf6cd1809fa7f510812f5b052f578c4, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.266724, -123.104824)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.266724,-123.104824&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 9
# Working on station_id: 0cf6cd1809fa7f510812f5b052f578c4, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.266724, -123.104824)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.266724,-123.104824&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 49
# Working on station_id: 0cf6cd1809fa7f510812f5b052f578c4, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.266724, -123.104824)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.266724,-123.104824&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0cf6cd1809fa7f510812f5b052f578c4, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.266724, -123.104824)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.266724,-123.104824&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0cf6cd1809fa7f510812f5b052f578c4, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.266724, -123.104824)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.266724,-123.104824&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 21
# Working on station_id: 0cf6cd1809fa7f510812f5b052f578c4, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.266724, -123.104824)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.266724,-123.104824&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 9
# ************** New Station! **************
# Working on station_id: 0d1b5c62f8d22e3650811df55596e25b, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.256845, -123.120071)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.256845,-123.120071&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 1
# Working on station_id: 0d1b5c62f8d22e3650811df55596e25b, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.256845, -123.120071)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.256845,-123.120071&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 47
# Working on station_id: 0d1b5c62f8d22e3650811df55596e25b, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.256845, -123.120071)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.256845,-123.120071&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 2
# Working on station_id: 0d1b5c62f8d22e3650811df55596e25b, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.256845, -123.120071)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.256845,-123.120071&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: 0d1b5c62f8d22e3650811df55596e25b, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.256845, -123.120071)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.256845,-123.120071&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 10
# Working on station_id: 0d1b5c62f8d22e3650811df55596e25b, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.256845, -123.120071)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.256845,-123.120071&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 14
# ************** New Station! **************
# Working on station_id: 0e0aef6fabaa808b3a3cef24657257a4, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.279259, -123.119145)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.279259,-123.119145&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 9
# Working on station_id: 0e0aef6fabaa808b3a3cef24657257a4, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.279259, -123.119145)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.279259,-123.119145&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 50
# ...
#           number rows = 6
# Working on station_id: fad9ebcf614dd1a72593a34072ff76f8, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.279938, -123.127478)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.279938,-123.127478&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 50
# Working on station_id: fad9ebcf614dd1a72593a34072ff76f8, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.279938, -123.127478)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.279938,-123.127478&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: fad9ebcf614dd1a72593a34072ff76f8, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.279938, -123.127478)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.279938,-123.127478&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: fad9ebcf614dd1a72593a34072ff76f8, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.279938, -123.127478)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.279938,-123.127478&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 25
# Working on station_id: fad9ebcf614dd1a72593a34072ff76f8, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.279938, -123.127478)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.279938,-123.127478&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 50
# ************** New Station! **************
# Working on station_id: fbb1d30d7f30b049873f5be5688563d4, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.28602, -123.116624)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.28602,-123.116624&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 10
# Working on station_id: fbb1d30d7f30b049873f5be5688563d4, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.28602, -123.116624)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.28602,-123.116624&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: fbb1d30d7f30b049873f5be5688563d4, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.28602, -123.116624)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.28602,-123.116624&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 3
# Working on station_id: fbb1d30d7f30b049873f5be5688563d4, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.28602, -123.116624)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.28602,-123.116624&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: fbb1d30d7f30b049873f5be5688563d4, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.28602, -123.116624)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.28602,-123.116624&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 13
# Working on station_id: fbb1d30d7f30b049873f5be5688563d4, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.28602, -123.116624)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.28602,-123.116624&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 50
# ************** New Station! **************
# Working on station_id: fbb4c06b719596c21f91fd51ef6d4710, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.265089, -123.119425)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.265089,-123.119425&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 4
# Working on station_id: fbb4c06b719596c21f91fd51ef6d4710, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.265089, -123.119425)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.265089,-123.119425&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 34
# Working on station_id: fbb4c06b719596c21f91fd51ef6d4710, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.265089, -123.119425)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.265089,-123.119425&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: fbb4c06b719596c21f91fd51ef6d4710, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.265089, -123.119425)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.265089,-123.119425&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: fbb4c06b719596c21f91fd51ef6d4710, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.265089, -123.119425)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.265089,-123.119425&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 19
# Working on station_id: fbb4c06b719596c21f91fd51ef6d4710, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.265089, -123.119425)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.265089,-123.119425&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 12
# ************** New Station! **************
# Working on station_id: fe0c57d04d6e682d284d501446095fc9, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.277595, -123.09583)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.277595,-123.09583&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 16
# Working on station_id: fe0c57d04d6e682d284d501446095fc9, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.277595, -123.09583)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.277595,-123.09583&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 46
# Working on station_id: fe0c57d04d6e682d284d501446095fc9, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.277595, -123.09583)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.277595,-123.09583&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 4
# Working on station_id: fe0c57d04d6e682d284d501446095fc9, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.277595, -123.09583)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.277595,-123.09583&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: fe0c57d04d6e682d284d501446095fc9, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.277595, -123.09583)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.277595,-123.09583&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 19
# Working on station_id: fe0c57d04d6e682d284d501446095fc9, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.277595, -123.09583)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.277595,-123.09583&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 27
# ************** New Station! **************
# Working on station_id: fedff7a263c182df94bda7307059cc52, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.277141, -123.122589)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.277141,-123.122589&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 6
# Working on station_id: fedff7a263c182df94bda7307059cc52, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.277141, -123.122589)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.277141,-123.122589&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 50
# Working on station_id: fedff7a263c182df94bda7307059cc52, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.277141, -123.122589)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.277141,-123.122589&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 1
# Working on station_id: fedff7a263c182df94bda7307059cc52, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.277141, -123.122589)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.277141,-123.122589&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: fedff7a263c182df94bda7307059cc52, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.277141, -123.122589)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.277141,-123.122589&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 22
# Working on station_id: fedff7a263c182df94bda7307059cc52, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.277141, -123.122589)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.277141,-123.122589&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 50
# ************** New Station! **************
# Working on station_id: fef69fb400210d861107a61db954d037, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.279821, -123.10802)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.279821,-123.10802&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 22
# Working on station_id: fef69fb400210d861107a61db954d037, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.279821, -123.10802)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.279821,-123.10802&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 50
# Working on station_id: fef69fb400210d861107a61db954d037, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.279821, -123.10802)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.279821,-123.10802&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 6
# Working on station_id: fef69fb400210d861107a61db954d037, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.279821, -123.10802)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.279821,-123.10802&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: fef69fb400210d861107a61db954d037, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.279821, -123.10802)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.279821,-123.10802&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 20
# Working on station_id: fef69fb400210d861107a61db954d037, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.279821, -123.10802)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.279821,-123.10802&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 50
# ************** New Station! **************
# Working on station_id: fffd87607aaae16fbb1f71615cbe7d17, categories being sent is: 10027,10047,10059,10069 (Arts and Entertainment: Museum|Public Art)
#      station_lat, station_long = (49.263518, -123.09568)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.263518,-123.09568&radius=1000&categories=10027,10047,10059,10069&limit=50&sort_by=distance
#           number rows = 1
# Working on station_id: fffd87607aaae16fbb1f71615cbe7d17, categories being sent is: 13032 (Dining and Drinking: Cafe, Coffee and Tea House)
#      station_lat, station_long = (49.263518, -123.09568)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.263518,-123.09568&radius=1000&categories=13032&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: fffd87607aaae16fbb1f71615cbe7d17, categories being sent is: 16003,16020,16046 (Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout)
#      station_lat, station_long = (49.263518, -123.09568)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.263518,-123.09568&radius=1000&categories=16003,16020,16046&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: fffd87607aaae16fbb1f71615cbe7d17, categories being sent is: 16004 (Bike Trail)
#      station_lat, station_long = (49.263518, -123.09568)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.263518,-123.09568&radius=1000&categories=16004&limit=50&sort_by=distance
#           number rows = 0
# Working on station_id: fffd87607aaae16fbb1f71615cbe7d17, categories being sent is: 16032 (Park)
#      station_lat, station_long = (49.263518, -123.09568)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.263518,-123.09568&radius=1000&categories=16032&limit=50&sort_by=distance
#           number rows = 18
# Working on station_id: fffd87607aaae16fbb1f71615cbe7d17, categories being sent is: 19010,19013,19014,19019 (Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental)
#      station_lat, station_long = (49.263518, -123.09568)
#      Calling API: request_url = https://api.foursquare.com/v3/places/search?ll=49.263518,-123.09568&radius=1000&categories=19010,19013,19014,19019&limit=50&sort_by=distance
#           number rows = 6

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
rolling_df.shape
# Out:
# (18007, 11)

# %%
rolling_df.head(50)
# Out:
#                           station_id                  place_id  \
# 0   00fa94ad698dc4a9e4d708d6fd32f294  4b5b84c0f964a5202f0429e3
# 1   00fa94ad698dc4a9e4d708d6fd32f294  4ded40b4fa76b21ed97ff4db
# 2   00fa94ad698dc4a9e4d708d6fd32f294  4e5955281f6e804280c4bad1
# 3   00fa94ad698dc4a9e4d708d6fd32f294  4aa9ac4ff964a520cc5420e3
# 4   00fa94ad698dc4a9e4d708d6fd32f294  52c72fe5498edf109f363e18
# 5   00fa94ad698dc4a9e4d708d6fd32f294  4ad008e2f964a5205fd720e3
# 6   00fa94ad698dc4a9e4d708d6fd32f294  52e19f99498ee190912a3ff0
# 7   00fa94ad698dc4a9e4d708d6fd32f294  531f860e498e932bf3c1ecfb
# 8   00fa94ad698dc4a9e4d708d6fd32f294  4acfe023f964a52099d620e3
# 9   00fa94ad698dc4a9e4d708d6fd32f294  4b197914f964a520f8dd23e3
# 10  00fa94ad698dc4a9e4d708d6fd32f294  4aebd797f964a520f6c421e3
# 11  00fa94ad698dc4a9e4d708d6fd32f294  4aa97278f964a520b25320e3
# 12  00fa94ad698dc4a9e4d708d6fd32f294  59f945fe1213846ef0fa8565
# 13  00fa94ad698dc4a9e4d708d6fd32f294  4bfb0f1e65fbc9b6d1ef906c
# 14  00fa94ad698dc4a9e4d708d6fd32f294  4ab13883f964a520986820e3
# 15  00fa94ad698dc4a9e4d708d6fd32f294  5968495bbcbf7a5c8a65f56d
# 16  00fa94ad698dc4a9e4d708d6fd32f294  4d0bef4b6a216ea8f1e3d81d
# 17  00fa94ad698dc4a9e4d708d6fd32f294  54ee68c4498eac22e3209227
# 18  00fa94ad698dc4a9e4d708d6fd32f294  4afa294cf964a5201e1722e3
# 19  00fa94ad698dc4a9e4d708d6fd32f294  5bfee70360d11b002c6c95ed
# 20  00fa94ad698dc4a9e4d708d6fd32f294  4da627771e722893cd1a9af8
# 21  00fa94ad698dc4a9e4d708d6fd32f294  4aa97571f964a520c25320e3
# 22  00fa94ad698dc4a9e4d708d6fd32f294  5810e16338fa28f23150d994
# 23  00fa94ad698dc4a9e4d708d6fd32f294  5f7a1ff398df6d72aa1bcfce
# 24  00fa94ad698dc4a9e4d708d6fd32f294  5bc293e4dd8442002ca2afb9
# 25  00fa94ad698dc4a9e4d708d6fd32f294  5da107902c1e910008b78e2c
# 26  00fa94ad698dc4a9e4d708d6fd32f294  58a5d1b52b04f80dbc98b531
# 27  00fa94ad698dc4a9e4d708d6fd32f294  4b6f7db4f964a520bdf22ce3
# 28  00fa94ad698dc4a9e4d708d6fd32f294  4feb9860e4b0cb016233ea14
# 29  00fa94ad698dc4a9e4d708d6fd32f294  5d3372a790a6f600084e8578
# 30  00fa94ad698dc4a9e4d708d6fd32f294  58ceff8e03e29a59cc462afa
# 31  00fa94ad698dc4a9e4d708d6fd32f294  591f594e67a9fe5d954f48f6
# 32  00fa94ad698dc4a9e4d708d6fd32f294  340a306b38b2421d008540b7
# 33  00fa94ad698dc4a9e4d708d6fd32f294  0cf26ad97e8b40b5d624c3ce
# 34  00fa94ad698dc4a9e4d708d6fd32f294  2f31389ec4d846758c6696db
# 35  00fa94ad698dc4a9e4d708d6fd32f294  4bcbdf5268f976b049e86183
# 36  00fa94ad698dc4a9e4d708d6fd32f294  4c0b1f677e3fc928cdebf482
# 37  00fa94ad698dc4a9e4d708d6fd32f294  51ddda78454aa8484cd0c086
# 38  00fa94ad698dc4a9e4d708d6fd32f294  4e78cd51b61ce1c898b38c89
# 39  00fa94ad698dc4a9e4d708d6fd32f294  55cf8649498e3e165e921863
# 40  00fa94ad698dc4a9e4d708d6fd32f294  4bf03a32d4e4d13a8d0716a7
# 41  00fa94ad698dc4a9e4d708d6fd32f294  51e49d88498e7ce6654db1ca
# 42  00fa94ad698dc4a9e4d708d6fd32f294  4c49fa7642b4d13aefbe8c7c
# 43  00fa94ad698dc4a9e4d708d6fd32f294  4f44ffafe4b062c96222bb59
# 44  00fa94ad698dc4a9e4d708d6fd32f294  4f9f0ec6e4b0d2bd64e32eb4
# 45  00fa94ad698dc4a9e4d708d6fd32f294  4d2680cdb818a35d5635838a
# 46  00fa94ad698dc4a9e4d708d6fd32f294  4dbc32d44b222080d38aecaf
# 47  00fa94ad698dc4a9e4d708d6fd32f294  520ece2611d2d4c4bfd3dd62
# 48  00fa94ad698dc4a9e4d708d6fd32f294  56b9224c498ea9a1a749bece
# 49  00fa94ad698dc4a9e4d708d6fd32f294  56b92207498eddb51af3c67f
#
#                                        name  distance                 address  \
# 0                              The Inukshuk     869.0          1700 Beach Ave
# 1            Lord Stanley of Preston statue     747.0     900 Stanley Park Dr
# 2                       Roedde House Museum     833.0         1415 Barclay St
# 3                           Cardero Bottega     647.0         1016 Cardero St
# 4                            Greenhorn Cafe     760.0           994 Nicola St
# 5                     Delany's Coffee House     413.0          1105 Denman St
# 6                                Pappa Roti     793.0          1505 Robson St
# 7                   JJ Bean Coffee Roasters     637.0         1209 Bidwell St
# 8                                 Starbucks     518.0           1795 Davie St
# 9                         Red Umbrella Cafe     625.0           1707 Davie St
# 10                              Take 5 Cafe     816.0           683 Nicola St
# 11                             Blenz Coffee     298.0           935 Denman St
# 12                  Yifang Taiwan Fruit Tea     476.0          1725 Robson St
# 13                           Cafe Villaggio     944.0  1506 Coal Harbour Quay
# 14                                Starbucks     382.0           785 Denman St
# 15                              Tim Hortons     304.0          1001 Denman St
# 16                                Starbucks     428.0          1766 Robson St
# 17                            Breaking Bean     810.0          551 Cardero St
# 18                             Bubble World     995.0          1325 Robson St
# 19                    Breka Bakery and Cafe     351.0           821 Denman St
# 20           Milano Espresso Bar and Gelato     325.0           849 Denman St
# 21                             Blenz Coffee     656.0          1615 Robson St
# 22                          3 Quarters Full     390.0           1789 Comox St
# 23                  Ongba Vietnamese Eatery     324.0           976 Denman St
# 24                        TTOB Holdings Ltd     410.0          1112 Denman St
# 25                              Weather Tea     419.0           780 Denman St
# 26                           WFM Coffee Bar     506.0          1675 Robson St
# 27                                Starbucks     727.0           1661 Davie St
# 28           Concession by Cactus Club Café     616.0          1790 Beach Ave
# 29                               Kumme Cafe     641.0          1610 Robson St
# 30                           Market Veranda     650.0          1610 Robson St
# 31               45 Degree Bubble Tea House     935.0        1467 Pender St W
# 32                     D'oro Gelato e Caffè     396.0          1094 Denman St
# 33                  Engelsea Pizza and Cafe     470.0          1168 Denman St
# 34                             ChewyPeppers     626.0          1610 Robson St
# 35                        English Bay Beach     608.0               Beach Ave
# 36                             Second Beach     791.0    8501 Stanley Park Dr
# 37                              Bay Theatre     292.0           935 Denman St
# 38                     Seagull Stanley Park     659.0            W Georgia St
# 39                          Fellowship Bell     734.0                     N/A
# 40                  Barclay Heritage Square     808.0            1440 Haro St
# 41                             Cardero Park     921.0                     N/A
# 42  Variety Kids Water Park in Stanley Park    1454.0     715 Stanley Park Dr
# 43                                  The Gym     139.0                     N/A
# 44              Haro and Chilco Pocket Park     186.0                     N/A
# 45                    Stanley Park Dog Park     306.0               Lagoon Dr
# 46                    Devonian Harbour Park     485.0                     N/A
# 47                              Morton Park     494.0         1800 Morton Ave
# 48     The Other Playground at Second Beach     623.0                     N/A
# 49                      Ceperley Playground     631.0                     N/A
#
#          city   postal                    category_id  \
# 0   Vancouver      N/A        10047|13065|16016|19014
# 1   Vancouver  V6G 3E2                    10047|16026
# 2   Vancouver  V6G 1J6                          10030
# 3   Vancouver  V6G 2H1              13035|13039|13145
# 4   Vancouver  V6G 2C8              13034|13035|13065
# 5   Vancouver  V6G 2M7                    13035|13065
# 6   Vancouver  V6G 1C3              13002|13034|13035
# 7   Vancouver  V6G 2K7                    13035|13065
# 8   Vancouver  V6G 1W5                          13035
# 9   Vancouver  V6G 1W5              13034|13035|13051
# 10  Vancouver  V6G 3J2              13034|13035|13334
# 11  Vancouver  V6G 2L9                    13035|13065
# 12  Vancouver  V6G 1C9                          13036
# 13  Vancouver  V6G 3G1              13034|13035|13065
# 14  Vancouver  V6G 2L6                          13035
# 15  Vancouver  V6G 2M4                    13032|13065
# 16  Vancouver  V6G 1E2                          13035
# 17  Vancouver  V6G 3L2                    13034|13065
# 18  Vancouver  V6E 1C6              13034|13049|13128
# 19  Vancouver  V6G 2L7                    13034|13065
# 20  Vancouver  V6G 2L7                    13034|13065
# 21  Vancouver  V6G 1C8                    13035|13236
# 22  Vancouver  V6G 1P5              13002|13034|13035
# 23  Vancouver  V6G 2M1                    13032|13379
# 24  Vancouver  V6G 2M8                          13033
# 25  Vancouver  V6G 2L5              13033|13036|13065
# 26  Vancouver  V6G 1C8                          13035
# 27  Vancouver  V6G 0E1                          13035
# 28  Vancouver  V6G 0A8              13031|13036|13068
# 29  Vancouver  V6G 1C7                          13033
# 30  Vancouver  V6G 1C7                    13034|13035
# 31  Vancouver  V6G 2S3                          13033
# 32  Vancouver  V6G 2M8              13032|13046|13065
# 33  Vancouver  V6G 2M9                    13034|13064
# 34  Vancouver  V6G 1C7                    13034|13289
# 35  Vancouver  V6C 3C1                          16003
# 36  Vancouver  V6G 1Z4                          16003
# 37  Vancouver  V6G 2L9                          16020
# 38  Vancouver      N/A                          16020
# 39  Vancouver      N/A                          16020
# 40  Vancouver      N/A                          16032
# 41  Vancouver      N/A                          16032
# 42  Vancouver      N/A              10055|16032|19028
# 43  Vancouver      N/A                          16032
# 44        N/A      N/A                          16032
# 45  Vancouver      N/A                          16033
# 46  Vancouver      N/A                          16032
# 47  Vancouver  V6G 1Z1  13065|16028|16032|18000|19014
# 48  Vancouver      N/A                          16037
# 49  Vancouver      N/A                          16037
#
#                                         category_name  \
# 0                Public Art|Restaurant|Fountain|Hotel
# 1                                 Public Art|Monument
# 2                                      History Museum
# 3               Coffee Shop|Deli|Fast Food Restaurant
# 4                         Café|Coffee Shop|Restaurant
# 5                              Coffee Shop|Restaurant
# 6                             Bakery|Café|Coffee Shop
# 7                              Coffee Shop|Restaurant
# 8                                         Coffee Shop
# 9                Café|Coffee Shop|Fish and Chips Shop
# 10                     Café|Coffee Shop|Sandwich Spot
# 11                             Coffee Shop|Restaurant
# 12                                           Tea Room
# 13                        Café|Coffee Shop|Restaurant
# 14                                        Coffee Shop
# 15             Cafe, Coffee, and Tea House|Restaurant
# 16                                        Coffee Shop
# 17                                    Café|Restaurant
# 18                    Café|Diner|Taiwanese Restaurant
# 19                                    Café|Restaurant
# 20                                    Café|Restaurant
# 21                     Coffee Shop|Italian Restaurant
# 22                            Bakery|Café|Coffee Shop
# 23  Cafe, Coffee, and Tea House|Vietnamese Restaurant
# 24                                    Bubble Tea Shop
# 25                Bubble Tea Shop|Tea Room|Restaurant
# 26                                        Coffee Shop
# 27                                        Coffee Shop
# 28          Burger Joint|Tea Room|American Restaurant
# 29                                    Bubble Tea Shop
# 30                                   Café|Coffee Shop
# 31                                    Bubble Tea Shop
# 32  Cafe, Coffee, and Tea House|Ice Cream Parlor|R...
# 33                                      Café|Pizzeria
# 34                             Café|Korean Restaurant
# 35                                              Beach
# 36                                              Beach
# 37                        Historic and Protected Site
# 38                        Historic and Protected Site
# 39                        Historic and Protected Site
# 40                                               Park
# 41                                               Park
# 42    Water Park|Park|Tourist Information and Service
# 43                                               Park
# 44                                               Park
# 45                                           Dog Park
# 46                                               Park
# 47  Restaurant|Nature Preserve|Park|Sports and Rec...
# 48                                         Playground
# 49                                         Playground
#
#            query_categories                                query_category_text
# 0   10027,10047,10059,10069          Arts and Entertainment: Museum|Public Art
# 1   10027,10047,10059,10069          Arts and Entertainment: Museum|Public Art
# 2   10027,10047,10059,10069          Arts and Entertainment: Museum|Public Art
# 3                     13032    Dining and Drinking: Cafe, Coffee and Tea House
# 4                     13032    Dining and Drinking: Cafe, Coffee and Tea House
# 5                     13032    Dining and Drinking: Cafe, Coffee and Tea House
# 6                     13032    Dining and Drinking: Cafe, Coffee and Tea House
# 7                     13032    Dining and Drinking: Cafe, Coffee and Tea House
# 8                     13032    Dining and Drinking: Cafe, Coffee and Tea House
# 9                     13032    Dining and Drinking: Cafe, Coffee and Tea House
# 10                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 11                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 12                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 13                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 14                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 15                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 16                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 17                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 18                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 19                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 20                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 21                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 22                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 23                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 24                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 25                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 26                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 27                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 28                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 29                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 30                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 31                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 32                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 33                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 34                    13032    Dining and Drinking: Cafe, Coffee and Tea House
# 35        16003,16020,16046  Landmarks and Outdoors: Beach|Historic Site|Sc...
# 36        16003,16020,16046  Landmarks and Outdoors: Beach|Historic Site|Sc...
# 37        16003,16020,16046  Landmarks and Outdoors: Beach|Historic Site|Sc...
# 38        16003,16020,16046  Landmarks and Outdoors: Beach|Historic Site|Sc...
# 39        16003,16020,16046  Landmarks and Outdoors: Beach|Historic Site|Sc...
# 40                    16032                                               Park
# 41                    16032                                               Park
# 42                    16032                                               Park
# 43                    16032                                               Park
# 44                    16032                                               Park
# 45                    16032                                               Park
# 46                    16032                                               Park
# 47                    16032                                               Park
# 48                    16032                                               Park
# 49                    16032                                               Park

# %%
rolling_df.groupby('query_category_text').size()
# Out:
# query_category_text
# Arts and Entertainment: Museum|Public Art                      1081
# Bike Trail                                                       26
# Dining and Drinking: Cafe, Coffee and Tea House                8113
# Landmarks and Outdoors: Beach|Historic Site|Scenic Lookout      537
# Park                                                           3861
# Travel and Transportation: B&B|Hostel|Hotel|Vacation Rental    4389
# dtype: int64

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# Save the dataframe as .csv file

rolling_df.to_csv('../data/fsq_vancouver.csv', index=False)  # Saved on 2023-10-20 afternoon

# %% [markdown]
# # Yelp

# %% [markdown]
# ## Julie's Notes:
#
# From Yelp categories list (https://docs.developer.yelp.com/docs/resources-categories), I compiled the following categories (sometimes combined) which I will send with the "categories" query parameter for each bike station location:
#
# <img src='../images/yelp_categories.png'>
#
# These decisions attempt to optimize the tension between API call limit (500 per day) and response item limit (maxxes out at 50 items).

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
# Pull my YELP API key into a variable
YELP_KEY = os.getenv('YELP_API_KEY')

# %%
# Substitute this until we can get it working
import json
json_file = open('C:/Users/raref/Lighthouse/W05D02_Data_Wrangling_Challenge_Walkthrough/Other_data_types_exercise/payload_postman_cambie_yelp_coffee.json', 'r')
payload_dict = json.load(json_file)
payload_dict
# Out:
# {'businesses': [{'id': '6iOAgzJ0DRZNSKA3FSrrOg',
#    'alias': 'la-taqueria-pinche-taco-shop-vancouver',
#    'name': 'La Taqueria Pinche Taco Shop',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fjhIj3XKuQ4mquD4Mg8OoQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-taqueria-pinche-taco-shop-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 683,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.263559, 'longitude': -123.112736},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2450 Yukon Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 3V6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2450 Yukon Street',
#      'Vancouver, BC V5Z 3V6',
#      'Canada']},
#    'phone': '+16045582549',
#    'display_phone': '+1 604-558-2549',
#    'distance': 169.51745604912014},
#   {'id': 'XAH2HpuUUtu7CUO26pbs4w',
#    'alias': 'saku-vancouver-8',
#    'name': 'Saku',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mKOSejpgcOkslnUydp0vSg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saku-vancouver-8?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 232,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2631006, 'longitude': -123.11667523250104},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '548 W Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1E9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['548 W Broadway', 'Vancouver, BC V5Z 1E9', 'Canada']},
#    'phone': '+16044234600',
#    'display_phone': '+1 604-423-4600',
#    'distance': 178.8453436692719},
#   {'id': '4118Aq9LbkvUr4s719uUkA',
#    'alias': 'uma-sushi-vancouver',
#    'name': 'Uma Sushi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gE3vdj8OS0PdjpKrjsGSeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uma-sushi-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 115,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2638048, 'longitude': -123.1137294},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '450 W 8th Avenue',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Y 1N9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['450 W 8th Avenue',
#      'Vancouver, BC V5Y 1N9',
#      'Canada']},
#    'phone': '+16044288588',
#    'display_phone': '+1 604-428-8588',
#    'distance': 152.15789734503988},
#   {'id': 'nkDZY5xqihF3XtZMzzfqqg',
#    'alias': 'hokkaido-ramen-santouka-vancouver-5',
#    'name': 'Hokkaido Ramen Santouka',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9Fe-Lqjx8cng9bBCB8MiKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hokkaido-ramen-santouka-vancouver-5?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 225,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.263127, 'longitude': -123.1168917},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '558 W Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1E9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['558 W Broadway', 'Vancouver, BC V5Z 1E9', 'Canada']},
#    'phone': '+16045651770',
#    'display_phone': '+1 604-565-1770',
#    'distance': 191.04423406538024},
#   {'id': 'Zi8Ywk36Ws_4zjw2gjMMFA',
#    'alias': 'iden-and-quan-ju-de-beijing-duck-house-vancouver-4',
#    'name': 'iDen & Quan Ju De Beijing Duck House',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yBiWyKn8E21c3rQn4AdjxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/iden-and-quan-ju-de-beijing-duck-house-vancouver-4?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 106,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.26021, 'longitude': -123.1148451},
#    'transactions': [],
#    'location': {'address1': '2808 Cambie Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 2V5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2808 Cambie Street',
#      'Vancouver, BC V5Z 2V5',
#      'Canada']},
#    'phone': '+12364777777',
#    'display_phone': '+1 236-477-7777',
#    'distance': 263.641336489585},
#   {'id': 'F5wxgIiZE7LYQxgqhI483A',
#    'alias': 'seaport-city-seafood-restaurant-vancouver',
#    'name': 'Seaport City Seafood Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/suTnAZrL624_a3FE-B4mZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/seaport-city-seafood-restaurant-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 31,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.263921119674905, 'longitude': -123.115152},
#    'transactions': [],
#    'location': {'address1': '2425 Cambie Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 4M5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2425 Cambie Street',
#      'Vancouver, BC V5Z 4M5',
#      'Canada']},
#    'phone': '+16042227288',
#    'display_phone': '+1 604-222-7288',
#    'distance': 168.6152620637239},
#   {'id': 'NensKn1MSVU_rm-1Y6WlFA',
#    'alias': 'marulilu-cafe-vancouver',
#    'name': 'Marulilu Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uwwarfUGQaB7hJYsr6YddQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marulilu-cafe-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 287,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.26338, 'longitude': -123.11415},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '451 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Y 1R4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['451 W Broadway', 'Vancouver, BC V5Y 1R4', 'Canada']},
#    'phone': '+16045684211',
#    'display_phone': '+1 604-568-4211',
#    'distance': 102.3298169925688},
#   {'id': 'oHYOa9l5aLOQpJ8dF6sDmA',
#    'alias': 'menya-raizo-vancouver',
#    'name': 'Menya Raizo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G0cHCtHIicWb4b8-rRGOhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/menya-raizo-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 77,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.26336, 'longitude': -123.11314},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '401 W Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Y 4A8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['401 W Broadway', 'Vancouver, BC V5Y 4A8', 'Canada']},
#    'phone': '+16048290697',
#    'display_phone': '+1 604-829-0697',
#    'distance': 133.67867312458677},
#   {'id': 'u-tcnG8zdDG8QWYTctxyfg',
#    'alias': 'cactus-club-cafe-vancouver',
#    'name': 'Cactus Club Cafe',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/C2z-w6Eaqx_lrpRrEOXC0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cactus-club-cafe-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 146,
#    'categories': [{'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2633734327403,
#     'longitude': -123.117130327243},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '575 Broadway W',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1E6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['575 Broadway W', 'Vancouver, BC V5Z 1E6', 'Canada']},
#    'phone': '+16047146000',
#    'display_phone': '+1 604-714-6000',
#    'distance': 221.48393348384232},
#   {'id': 'AEOyRbQtYD3bmX1qJWvt4g',
#    'alias': 'peaceful-restaurant-vancouver',
#    'name': 'Peaceful Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Otuhde5EA5-5sNr-Q9oAaA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/peaceful-restaurant-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 621,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.263147, 'longitude': -123.116143},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '110-532 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1E9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['110-532 W Broadway',
#      'Vancouver, BC V5Z 1E9',
#      'Canada']},
#    'phone': '+16048799878',
#    'display_phone': '+1 604-879-9878',
#    'distance': 146.41800874604075},
#   {'id': 'gdSAYWUI2MTgrk08r_OZSg',
#    'alias': 'heritage-asian-eatery-vancouver-4',
#    'name': 'Heritage Asian Eatery',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/C-JhT-S2YZ6XrU785awaLw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heritage-asian-eatery-vancouver-4?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 87,
#    'categories': [{'alias': 'panasian', 'title': 'Pan Asian'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.26287, 'longitude': -123.11247},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '382 W Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Y 1R2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['382 W Broadway', 'Vancouver, BC V5Y 1R2', 'Canada']},
#    'phone': '+16045596058',
#    'display_phone': '+1 604-559-6058',
#    'distance': 152.16830796850962},
#   {'id': 'mvCO6pRpfMB0_1GLlwgZRw',
#    'alias': 'sushi-california-vancouver',
#    'name': 'Sushi California',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/szO9C24rENcsl974my8prg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-california-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 319,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2630454633729,
#     'longitude': -123.112614326016},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '388 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Y 4A8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['388 W Broadway', 'Vancouver, BC V5Y 4A8', 'Canada']},
#    'phone': '+16048738284',
#    'display_phone': '+1 604-873-8284',
#    'distance': 143.49216961439387},
#   {'id': 'JcxSnoXt1q6LdSEgwJsdRQ',
#    'alias': 'rogue-kitchen-and-wetbar-vancouver-2',
#    'name': 'Rogue Kitchen & Wetbar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/MIFj7hD28cwdz8CFQ3AHuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rogue-kitchen-and-wetbar-vancouver-2?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 146,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.263047, 'longitude': -123.117827},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '602 West Broadway Avenue',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 3J2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['602 West Broadway Avenue',
#      'Vancouver, BC V5Z 3J2',
#      'Canada']},
#    'phone': '+16045689400',
#    'display_phone': '+1 604-568-9400',
#    'distance': 256.56802477141},
#   {'id': 'pJge_LJ3NV8iQtrERe6AyQ',
#    'alias': 'indian-roti-kitchen-vancouver',
#    'name': 'Indian Roti Kitchen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/0XTrwPFf4uiG7s2-c-ZXGg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/indian-roti-kitchen-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 159,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.25901, 'longitude': -123.11538},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2961 Cambie Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 2V7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2961 Cambie Street',
#      'Vancouver, BC V5Z 2V7',
#      'Canada']},
#    'phone': '+16048763767',
#    'display_phone': '+1 604-876-3767',
#    'distance': 391.28316184456656},
#   {'id': 'bJKqZi70hu8g_ctZAAxtJw',
#    'alias': 'yolks-vancouver',
#    'name': 'Yolks',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pMck3VWL7RDxo7KC_UqMwg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yolks-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 353,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2631139, 'longitude': -123.1163529},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '546 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1E9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['546 W Broadway', 'Vancouver, BC V5Z 1E9', 'Canada']},
#    'phone': '+16045599655',
#    'display_phone': '+1 604-559-9655',
#    'distance': 170.3240366141957},
#   {'id': 'raZ-NDBs9S1j9fPONh4fWw',
#    'alias': 'vijs-restaurant-vancouver-2',
#    'name': "Vij's Restaurant",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hmu5Wa7aihzbJAw1NeakIA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vijs-restaurant-vancouver-2?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 401,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.25754, 'longitude': -123.11479},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '3106 Cambie Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 2W2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3106 Cambie Street',
#      'Vancouver, BC V5Z 2W2',
#      'Canada']},
#    'phone': '+16047366664',
#    'display_phone': '+1 604-736-6664',
#    'distance': 547.5967510908013},
#   {'id': 'qebPYEXBp8Zo_d7GY50i2w',
#    'alias': 'westcoast-poke-vancouver-6',
#    'name': 'Westcoast Poke',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LAiYPFq4eC-Kb16HIhvoAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/westcoast-poke-vancouver-6?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 172,
#    'categories': [{'alias': 'hawaiian', 'title': 'Hawaiian'},
#     {'alias': 'poke', 'title': 'Poke'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.26409, 'longitude': -123.1140415},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '463 W 8th Avenue',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Y 3Z5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['463 W 8th Avenue',
#      'Vancouver, BC V5Y 3Z5',
#      'Canada']},
#    'phone': '+17783795344',
#    'display_phone': '+1 778-379-5344',
#    'distance': 182.23995143895965},
#   {'id': 'l184Y1d3oAa5_Al4YIaRjQ',
#    'alias': 'anh-and-chi-vancouver',
#    'name': 'Anh and Chi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pMvur_cjBwQ3nz1ye5PJeQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/anh-and-chi-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 638,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2550314422938,
#     'longitude': -123.100882202153},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3388 Main Street',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5V 3M7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3388 Main Street',
#      'Vancouver, BC V5V 3M7',
#      'Canada']},
#    'phone': '+16048788883',
#    'display_phone': '+1 604-878-8883',
#    'distance': 1284.2105761524042},
#   {'id': 'PrKpa6Ejv1v1WvIIywYMvg',
#    'alias': 'aperture-coffee-bar-vancouver-2',
#    'name': 'Aperture Coffee Bar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FCn4yLt9PJ1QUBv3PLWwVw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aperture-coffee-bar-vancouver-2?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 124,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2632037459, 'longitude': -123.110469593},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '243 W Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Y 3L1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['243 W Broadway', 'Vancouver, BC V5Y 3L1', 'Canada']},
#    'phone': '+16046208065',
#    'display_phone': '+1 604-620-8065',
#    'distance': 295.9249203529791},
#   {'id': 'yodp8dWdtD22DFp75nFa9A',
#    'alias': 'yu-shang-hot-pot-vancouver',
#    'name': 'Yu Shang Hot Pot',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HvSNI7LzNVNgV8iCN6R8Aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yu-shang-hot-pot-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 79,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.263149, 'longitude': -123.125629},
#    'transactions': ['restaurant_reservation'],
#    'location': {'address1': '202-950 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1K7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['202-950 W Broadway',
#      'Vancouver, BC V5Z 1K7',
#      'Canada']},
#    'phone': '+16045646686',
#    'display_phone': '+1 604-564-6686',
#    'distance': 818.3634334813887},
#   {'id': 'GZKiaocnz8xfoC-fA5Bn-w',
#    'alias': 'gyu-kaku-japanese-bbq-vancouver-3',
#    'name': 'Gyu-Kaku Japanese BBQ',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Fq2Icb4_VNGz6WiEy1LgNA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gyu-kaku-japanese-bbq-vancouver-3?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 198,
#    'categories': [{'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2633338, 'longitude': -123.1255837},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '#201-950 W. Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1K7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['#201-950 W. Broadway',
#      'Vancouver, BC V5Z 1K7',
#      'Canada']},
#    'phone': '+16045583898',
#    'display_phone': '+1 604-558-3898',
#    'distance': 817.2001774898488},
#   {'id': '31ag-M_QiaycGQrvAi169w',
#    'alias': 'jollibee-vancouver-2',
#    'name': 'Jollibee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pWlzXHTtMBPiSYuzdBRs-A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jollibee-vancouver-2?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 33,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.2628615714721, 'longitude': -123.1151665},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2549 Cambie Street',
#     'address2': None,
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 3Y6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2549 Cambie Street',
#      'Vancouver, BC V5Z 3Y6',
#      'Canada']},
#    'phone': '+16048001107',
#    'display_phone': '+1 604-800-1107',
#    'distance': 69.66140643042063},
#   {'id': 'uonaIMF0GOLC8UzKR3IaQA',
#    'alias': 'fable-diner-vancouver-2',
#    'name': 'Fable Diner',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/15q7X2JCNQlUCia888VGPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fable-diner-vancouver-2?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 332,
#    'categories': [{'alias': 'diners', 'title': 'Diners'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2630749, 'longitude': -123.1019822},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '151 E Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5T 1W1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['151 E Broadway', 'Vancouver, BC V5T 1W1', 'Canada']},
#    'phone': '+16045633463',
#    'display_phone': '+1 604-563-3463',
#    'distance': 936.8031868399968},
#   {'id': '-HfxEoo3wIWFApvuDcHEGg',
#    'alias': 'passion8-dessert-cafe-vancouver',
#    'name': 'Passion8 Dessert Cafe',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-gztELiRhLtHHn0a5QGtHg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/passion8-dessert-cafe-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 212,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.258435242883, 'longitude': -123.11499774456},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3010 Cambie Street',
#     'address2': None,
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 2V9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3010 Cambie Street',
#      'Vancouver, BC V5Z 2V9',
#      'Canada']},
#    'phone': '+17783798238',
#    'display_phone': '+1 778-379-8238',
#    'distance': 452.6386006273939},
#   {'id': '9hcYOm201hbMnR94AM6Cug',
#    'alias': 'lumiere-cafe-vancouver-3',
#    'name': 'Lumiere Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-QNPDgDmH8pZP0lGeUhypw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lumiere-cafe-vancouver-3?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 17,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.263468, 'longitude': -123.115865},
#    'transactions': [],
#    'location': {'address1': '521 West Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1E6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['521 West Broadway',
#      'Vancouver, BC V5Z 1E6',
#      'Canada']},
#    'phone': '+16044234555',
#    'display_phone': '+1 604-423-4555',
#    'distance': 150.32666176414975},
#   {'id': 'qO03dJ4hU0sb5I1eBSEVkA',
#    'alias': 'dynasty-seafood-restaurant-vancouver',
#    'name': 'Dynasty Seafood Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lxhlfiAP2TvTRSaYQfhxBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dynasty-seafood-restaurant-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 304,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cantonese', 'title': 'Cantonese'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.2635999, 'longitude': -123.12138},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '777 W Broadway',
#     'address2': 'Ste 108',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 4J7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['777 W Broadway',
#      'Ste 108',
#      'Vancouver, BC V5Z 4J7',
#      'Canada']},
#    'phone': '+16048768388',
#    'display_phone': '+1 604-876-8388',
#    'distance': 519.3882209068581},
#   {'id': 'KDpEDnHqRXTeBhNTmvBFiQ',
#    'alias': 'burgoo-bistros-vancouver',
#    'name': 'Burgoo Bistros',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/x7LscbOOV73GQSgJYOllkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/burgoo-bistros-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 502,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.25763, 'longitude': -123.10084},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3096 Main Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5T 3G5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3096 Main Street',
#      'Vancouver, BC V5T 3G5',
#      'Canada']},
#    'phone': '+16048731441',
#    'display_phone': '+1 604-873-1441',
#    'distance': 1123.6393947248894},
#   {'id': 'eUf08fT2qf-l8Ofi--sETw',
#    'alias': 'banana-leaf-vancouver-5',
#    'name': 'Banana Leaf',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/O92hRG3-XR9968de_LfHmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/banana-leaf-vancouver-5?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 301,
#    'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'singaporean', 'title': 'Singaporean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.26302, 'longitude': -123.1225},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '820 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1J8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['820 W Broadway', 'Vancouver, BC V5Z 1J8', 'Canada']},
#    'phone': '+16047316333',
#    'display_phone': '+1 604-731-6333',
#    'distance': 591.0680301495883},
#   {'id': '7mC73EaD-pi3yyR63ZVn3A',
#    'alias': 'the-cascade-room-vancouver',
#    'name': 'The Cascade Room',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7BHQmpgTD_YZg296Zjhehw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cascade-room-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 232,
#    'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#     {'alias': 'newcanadian', 'title': 'Canadian (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2617, 'longitude': -123.10062},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2616 Main Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5T 3E6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2616 Main Street',
#      'Vancouver, BC V5T 3E6',
#      'Canada']},
#    'phone': '+16047098650',
#    'display_phone': '+1 604-709-8650',
#    'distance': 992.5014069727342},
#   {'id': 'vGyDxnk9P975Rwrs05cdVw',
#    'alias': 'city-of-vancouver-vancouver-9',
#    'name': 'City of Vancouver',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lc5CRCeNIu9MUjcQiO1smg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-of-vancouver-vancouver-9?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 12,
#    'categories': [{'alias': 'localflavor', 'title': 'Local Flavor'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.26088379999999, 'longitude': -123.1139269},
#    'transactions': [],
#    'location': {'address1': '453 West 12th Avenue',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Y 1V4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['453 West 12th Avenue',
#      'Vancouver, BC V5Y 1V4',
#      'Canada']},
#    'phone': '+16048737000',
#    'display_phone': '+1 604-873-7000',
#    'distance': 181.502149453713},
#   {'id': 'FFVXF_4OnzTlWITF2IH5SQ',
#    'alias': 'maizal-rmf-vancouver-2',
#    'name': 'Maizal RMF',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/-oCz07UqmMCDyFdZjDNgKA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maizal-rmf-vancouver-2?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 146,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2600097, 'longitude': -123.1012988},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2815 Main Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5T 3G1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2815 Main Street',
#      'Vancouver, BC V5T 3G1',
#      'Canada']},
#    'phone': '+16047090813',
#    'display_phone': '+1 604-709-0813',
#    'distance': 985.2541936635806},
#   {'id': 'mrdjtCQqIs2U8WlMz40b7Q',
#    'alias': 'pablo-cheese-tart-vancouver',
#    'name': 'Pablo Cheese Tart',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/eUTDziSjFkgiPnXgY3SdDw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pablo-cheese-tart-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 17,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.26338, 'longitude': -123.11592},
#    'transactions': [],
#    'location': {'address1': '511 West Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1E6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['511 West Broadway',
#      'Vancouver, BC V5Z 1E6',
#      'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 135.82175499752597},
#   {'id': 'UkSNdIF54dvas25eh_CmFw',
#    'alias': 'caffe-cittadella-vancouver-2',
#    'name': 'Caffe Cittadella',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/j90XfuRbiG8UjEuVaOaUNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-cittadella-vancouver-2?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 157,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bistros', 'title': 'Bistros'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.264809386635505,
#     'longitude': -123.11726668221056},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2310 Ash Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 3C2',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2310 Ash Street', 'Vancouver, BC V5Z 3C2', 'Canada']},
#    'phone': '+16045685909',
#    'display_phone': '+1 604-568-5909',
#    'distance': 331.7346855105138},
#   {'id': 'rZNgrcmNQWqxS54FiNvxJw',
#    'alias': 'the-golden-horn-turkish-bakery-and-cafe-vancouver-2',
#    'name': 'The Golden Horn Turkish Bakery & Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OQzs2Et2DkZdNo2Ye6Ii_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-golden-horn-turkish-bakery-and-cafe-vancouver-2?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 12,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 49.25981092848732,
#     'longitude': -123.11528339982031},
#    'transactions': [],
#    'location': {'address1': '2857 Cambie Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 3Y8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2857 Cambie Street',
#      'Vancouver, BC V5Z 3Y8',
#      'Canada']},
#    'phone': '+16045660931',
#    'display_phone': '+1 604-566-0931',
#    'distance': 304.4381437217121},
#   {'id': 'JpdBIH7m3P338-MYsvSaqA',
#    'alias': 'pizzeria-grano-vancouver',
#    'name': 'Pizzeria Grano',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gE61SZZaOpeHjSwQ_BPabw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzeria-grano-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 26,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2561903, 'longitude': -123.1010467},
#    'transactions': [],
#    'location': {'address1': '3240 Main Street',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5V 3M5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3240 Main Street',
#      'Vancouver, BC V5V 3M5',
#      'Canada']},
#    'phone': '+16048765408',
#    'display_phone': '+1 604-876-5408',
#    'distance': 1196.3782614373533},
#   {'id': 'gRepmb_vwaCDzbsjwmJ-Ig',
#    'alias': 'foret-noire-patisserie-vancouver',
#    'name': 'Foret Noire Patisserie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/47ybvwtxgMsEHKQBq6n2AQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/foret-noire-patisserie-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 58,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.26284, 'longitude': -123.11051},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '236 West Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Y 1P6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['236 West Broadway',
#      'Vancouver, BC V5Y 1P6',
#      'Canada']},
#    'phone': '+12365213640',
#    'display_phone': '+1 236-521-3640',
#    'distance': 303.4822778067055},
#   {'id': 'wQMzD2Aw4ve0xzE9B9e1Vw',
#    'alias': 'simit-bakery-vancouver',
#    'name': 'Simit Bakery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/sm87suYPiex_c6-qg7gAvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/simit-bakery-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 38,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'bagels', 'title': 'Bagels'},
#     {'alias': 'turkish', 'title': 'Turkish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2632345, 'longitude': -123.1087722},
#    'transactions': [],
#    'location': {'address1': '191 West Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Y 1P4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['191 West Broadway',
#      'Vancouver, BC V5Y 1P4',
#      'Canada']},
#    'phone': '+16044233434',
#    'display_phone': '+1 604-423-3434',
#    'distance': 401.706104800421},
#   {'id': 'y583PSvm5c6tZYmRiboYYA',
#    'alias': 'a-bento-vancouver',
#    'name': 'A.Bento',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2Ger31IoeGBzDZiuzwu4Vw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/a-bento-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 28,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.263164, 'longitude': -123.118857},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '656W Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1G1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['656W Broadway', 'Vancouver, BC V5Z 1G1', 'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 332.2779541931938},
#   {'id': 'NPOkjob3PFlNrvZ-GO3fqQ',
#    'alias': 'the-firewood-café-vancouver-2',
#    'name': 'The Firewood Café',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Yy93sPGprgiZ22eEKRwU_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-firewood-caf%C3%A9-vancouver-2?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 120,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2584924, 'longitude': -123.1148336},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3004 Cambie Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 2V9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3004 Cambie Street',
#      'Vancouver, BC V5Z 2V9',
#      'Canada']},
#    'phone': '+16048730001',
#    'display_phone': '+1 604-873-0001',
#    'distance': 441.64497648210823},
#   {'id': 'NnaE4IKlc6XdYOUu4IOV5w',
#    'alias': '49th-parallel-coffee-vancouver-3',
#    'name': '49th Parallel Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HzIUnm4-aSt5Nm1r8X6Xbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/49th-parallel-coffee-vancouver-3?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 503,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'donuts', 'title': 'Donuts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2591330651218,
#     'longitude': -123.10088478104},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2902 Main Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5T 0C1',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2902 Main Street',
#      'Vancouver, BC V5T 0C1',
#      'Canada']},
#    'phone': '+16048724901',
#    'display_phone': '+1 604-872-4901',
#    'distance': 1049.0763609144662},
#   {'id': 'gcJAIjEHewjOi87obm6gXg',
#    'alias': 'pizza-rubato-napoletana-vancouver',
#    'name': 'Pizza Rubato Napoletana',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_B1_OdWp8YvHQ6Z3yF74Bg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizza-rubato-napoletana-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 9,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2635503, 'longitude': -123.1170685},
#    'transactions': [],
#    'location': {'address1': '561 W Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1E6',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['561 W Broadway', 'Vancouver, BC V5Z 1E6', 'Canada']},
#    'phone': '+16049090773',
#    'display_phone': '+1 604-909-0773',
#    'distance': 221.44468897546162},
#   {'id': 'zXNIn6HJ2bnOSj2iTYpQTg',
#    'alias': 'earnest-ice-cream-vancouver-4',
#    'name': 'Earnest Ice Cream',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_z9mGf7UleCw57EcyRqmzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/earnest-ice-cream-vancouver-4?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 386,
#    'categories': [{'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2688628769236,
#     'longitude': -123.102919221177},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1829 Quebec Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5T 2Z3',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['1829 Quebec Street',
#      'Vancouver, BC V5T 2Z3',
#      'Canada']},
#    'phone': '+17783790697',
#    'display_phone': '+1 778-379-0697',
#    'distance': 1093.7279551323757},
#   {'id': 'KN9zCrgwHj_iWQGEf3Vzyw',
#    'alias': 'tropika-on-cambie-vancouver-2',
#    'name': 'Tropika On Cambie',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JyRkLasaaMh98_gLIr46oQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tropika-on-cambie-vancouver-2?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 174,
#    'categories': [{'alias': 'malaysian', 'title': 'Malaysian'},
#     {'alias': 'singaporean', 'title': 'Singaporean'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 49.2589, 'longitude': -123.11538},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2975 Cambie Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 2V7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['2975 Cambie Street',
#      'Vancouver, BC V5Z 2V7',
#      'Canada']},
#    'phone': '+16048796002',
#    'display_phone': '+1 604-879-6002',
#    'distance': 400.9096698431295},
#   {'id': '8GSg9GAax8rRmBCij1aneA',
#    'alias': 'lotus-seed-vegan-vancouver',
#    'name': 'Lotus Seed Vegan',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Gmua4ZDOCUvAHfM5ig8QKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lotus-seed-vegan-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 129,
#    'categories': [{'alias': 'vegan', 'title': 'Vegan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 49.2631751, 'longitude': -123.1204905},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '736 W Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1G8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['736 W Broadway', 'Vancouver, BC V5Z 1G8', 'Canada']},
#    'phone': '+16045633368',
#    'display_phone': '+1 604-563-3368',
#    'distance': 480.6124056939926},
#   {'id': 'X-73k3cwBjjc170MOdPa7A',
#    'alias': 'elysian-coffee-vancouver',
#    'name': 'Elysian Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WyQL8tQEIl5M-fB9u04mMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elysian-coffee-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 210,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 49.26294, 'longitude': -123.11728},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '590 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 1E9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['590 W Broadway', 'Vancouver, BC V5Z 1E9', 'Canada']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 221.08064577489418},
#   {'id': 'vOpLZp0G7WnrDMNZYVIilQ',
#    'alias': 'wendys-vancouver-4',
#    'name': "Wendy's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uY1DvcomTQiThRFvOGqQ3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wendys-vancouver-4?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 51,
#    'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 49.26368, 'longitude': -123.11455},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '480 W. 8th Ave.',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Y 1N9',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['480 W. 8th Ave.', 'Vancouver, BC V5Y 1N9', 'Canada']},
#    'phone': '+16048758933',
#    'display_phone': '+1 604-875-8933',
#    'distance': 136.55584144406004},
#   {'id': 'sJ-mEiS2A5aFje7v3dhI4w',
#    'alias': 'cafe-and-life-co-vancouver',
#    'name': 'Cafe & Life Co.',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9eelGPfBHglejPA3lVPMdg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-and-life-co-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 13,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.265218, 'longitude': -123.116184},
#    'transactions': [],
#    'location': {'address1': '511 W 7th Avenue',
#     'address2': 'Suite 117',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 2T5',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['511 W 7th Avenue',
#      'Suite 117',
#      'Vancouver, BC V5Z 2T5',
#      'Canada']},
#    'phone': '+16043369888',
#    'display_phone': '+1 604-336-9888',
#    'distance': 330.1994594896762},
#   {'id': '1AA4EjIIXywxOSnbyZ9vLA',
#    'alias': 'pho-extreme-xe-lua-vancouver',
#    'name': 'Pho Extreme Xe Lua',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qs0NHDhcYHxCvztCdKBD3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pho-extreme-xe-lua-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 101,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 49.2633568993769,
#     'longitude': -123.114155144333},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '457 W Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Y 4A8',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['457 W Broadway', 'Vancouver, BC V5Y 4A8', 'Canada']},
#    'phone': '+16048798228',
#    'display_phone': '+1 604-879-8228',
#    'distance': 98.30752414020043},
#   {'id': '5nGTOnj9Fwb2hZUP3JQPVg',
#    'alias': 'pizzamia-gourmet-pizza-bar-vancouver',
#    'name': 'Pizzamia Gourmet Pizza Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C-sVWULLNT0QijlmUY-A_g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pizzamia-gourmet-pizza-bar-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 7,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2633224, 'longitude': -123.1132569},
#    'transactions': [],
#    'location': {'address1': '407 W Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Vancouver',
#     'zip_code': 'V5Y 1R4',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['407 W Broadway', 'Vancouver, BC V5Y 1R4', 'Canada']},
#    'phone': '+16047140037',
#    'display_phone': '+1 604-714-0037',
#    'distance': 132.11204593768818},
#   {'id': '77sOC9lw_YMSASa5VyIOUA',
#    'alias': 'rain-or-shine-ice-cream-vancouver-2',
#    'name': 'Rain or Shine Ice Cream',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/IKlnQ0KnqeQDypfkGpqRDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rain-or-shine-ice-cream-vancouver-2?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg',
#    'review_count': 242,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 49.2551458, 'longitude': -123.1149293},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '3382 Cambie Street',
#     'address2': '',
#     'address3': '',
#     'city': 'Vancouver',
#     'zip_code': 'V5Z 3K7',
#     'country': 'CA',
#     'state': 'BC',
#     'display_address': ['3382 Cambie Street',
#      'Vancouver, BC V5Z 3K7',
#      'Canada']},
#    'phone': '+16048769986',
#    'display_phone': '+1 604-876-9986',
#    'distance': 821.3676293841436}],
#  'total': 356,
#  'region': {'center': {'longitude': -123.114397, 'latitude': 49.262487}}}

# %%
# Function Definitions

# Define function that will make the GET request to Yelp
def yelp_get_request_business_search(station_latitude, station_longitude, radius, categories, API_KEY):

    base_yelp_endpoint = 'https://api.yelp.com/v3'
    business_search = '/businesses/search'

    # Default Query Parameters for all our GET requests, that aren't otherwise passed in
    limit = 50  # Always get as many as allowed
    sort_by = 'best_match'

    # Craft the request_url:
    request_url = base_yelp_endpoint + business_search + \
    '?' + \
    'latitude=' + str(station_latitude) + \
    '&longitude=' + str(station_longitude) + \
    '&radius=' + str(radius) + \
    '&categories=' + categories + \
    '&limit=' + str(limit) + \
    '&sort_by=' + sort_by

    header_dict = {
        'accept': 'application/json',
        'Authorization' : 'Bearer ' + API_KEY
        }
    
    # DEBUG
    #print(f"Inside yelp_get_request: request_url = {request_url}, header_dict = {header_dict}")

    # Make the call, get response out
    response = requests.get(request_url, headers=header_dict)

    # Return the payload_dict to caller
    return response.json()
    

# Define function that will create the default yelp_dict for each GET request:
def create_default_yelpdict(yelpdict):
    yelpdict.clear()
    yelpdict['station_id']= []
    yelpdict['place_id'] = []
    yelpdict['name'] = []
    yelpdict['distance'] = []
    yelpdict['address'] = []
    yelpdict['city'] = []
    yelpdict['postal'] = []
    yelpdict['review_count'] = []
    yelpdict['rating'] = []
    yelpdict['category_id'] = []
    yelpdict['category_name'] = []
    yelpdict['query_categories'] = []


# Define function that will parse the JSON-formatted response
def yelpdict_from_response(stationid, yelpdict, jsonpayload, query_categories):

    #print(f"I'm in yelpdict_from_response, and yelpdict is:\n{yelpdict}")
    businesses_array = jsonpayload['businesses']
    for biz in businesses_array:
        yelpdict['station_id'].append(stationid)
        yelpdict['place_id'].append(biz['id'])
        yelpdict['name'].append(biz['name'])
        yelpdict['distance'].append(biz['distance'])
        yelpdict['address'].append(biz['location']['address1'])
        yelpdict['city'].append(biz['location']['city'])
        yelpdict['postal'].append(biz['location']['zip_code'])
        yelpdict['review_count'].append(biz['review_count'])
        yelpdict['rating'].append(biz['rating'])

        categories_array = biz['categories']
        alias_string = ''
        title_string = ''
        for entry in categories_array:
            alias_string += entry['alias'] + '|'
            title_string += entry['title'] + '|'
        
        alias_string = alias_string[:-1]
        title_string = title_string[:-1]
        yelpdict['category_id'].append(alias_string)
        yelpdict['category_name'].append(title_string)
        yelpdict['query_categories'].append(query_categories)

    return yelpdict

# %%
mystation_latitude = 49.274566
mystation_longitude = -123.121817
mystation_id = '32603a87cfca71d0f7dfa3513bad69d5'
myradius=1000
mycategories='beaches,parks,bicyclepaths,mountainbiking,museums,hostels,hotels'
myresponse = yelp_get_request_business_search(mystation_latitude, mystation_longitude, myradius, mycategories, YELP_KEY)
print(myresponse)
#yelp_get_request_business_search(station_latitude, station_longitude, radius, categories, API_KEY)
# Out:
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.274566&longitude=-123.121817&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking,museums,hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer 6xI0usznZmRlsdcnN1DIEq7JF-iQbgkdkbfFbMrM99-4E2DWENHZnL2WmBZ0iUTcLxYksUg1AOMK9Q3FZzlJkDBXoMPTO6ngG_8FvSguqNZ3tBvYVDLT5Z7AHZsxZXYx'}
# {'businesses': [{'id': 'DIf1ux1zR8cHp9neCEoyYg', 'alias': 'opus-hotel-vancouver-vancouver-2', 'name': 'OPUS Hotel Vancouver', 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NY1Y1pQyXN9B49KodFqZHA/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/opus-hotel-vancouver-vancouver-2?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg', 'review_count': 179, 'categories': [{'alias': 'hotels', 'title': 'Hotels'}], 'rating': 4.5, 'coordinates': {'latitude': 49.2746672, 'longitude': -123.1225135}, 'transactions': [], 'price': '$$$', 'location': {'address1': '322 Davie Street', 'address2': '', 'address3': '', 'city': 'Vancouver', 'zip_code': 'V6B 5Z6', 'country': 'CA', 'state': 'BC', 'display_address': ['322 Davie Street', 'Vancouver, BC V6B 5Z6', 'Canada']}, 'phone': '+18666426787', 'display_phone': '+1 866-642-6787', 'distance': 51.767046784820565}, {'id': 'ESYgaAU5w7wdvhhHs3Wwsg', 'alias': 'rosewood-hotel-georgia-vancouver', 'name': 'Rosewood Hotel Georgia', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PYQDlbNnOUfgR2JzUTwnEw/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/rosewood-hotel-georgia-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg', 'review_count': 124, 'categories': [{'alias': 'hotels', 'title': 'Hotels'}], 'rating': 4.5, 'coordinates': {'latitude': 49.2833983034569, 'longitude': -123.119197295922}, 'transactions': [], 'price': '$$$$', 'location': {'address1': '801 W Georgia Street', 'address2': '', 'address3': '', 'city': 'Vancouver', 'zip_code': 'V6C 1P7', 'country': 'CA', 'state': 'BC', 'display_address': ['801 W Georgia Street', 'Vancouver, BC V6C 1P7', 'Canada']}, 'phone': '+16046825566', 'display_phone': '+1 604-682-5566', 'distance': 1000.3230551436324}, {'id': 'KwMakQ-ozY7U7OySlRb-Kw', 'alias': 'l-hermitage-hotel-vancouver', 'name': "L'Hermitage Hotel", 'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KKJ_-PYla7UQBFMGnFFjNQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/l-hermitage-hotel-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg', 'review_count': 149, 'categories': [{'alias': 'hotels', 'title': 'Hotels'}], 'rating': 4.5, 'coordinates': {'latitude': 49.28031, 'longitude': -123.1172}, 'transactions': [], 'price': '$$$', 'location': {'address1': '788 Richards Street', 'address2': '', 'address3': '', 'city': 'Vancouver', 'zip_code': 'V6B 3A4', 'country': 'CA', 'state': 'BC', 'display_address': ['788 Richards Street', 'Vancouver, BC V6B 3A4', 'Canada']}, 'phone': '+17783274100', 'display_phone': '+1 778-327-4100', 'distance': 737.6311370679358}, {'id': 'RP1UYKDHnFjXAj9ZqEHhOw', 'alias': 'jw-marriott-parq-vancouver-vancouver', 'name': 'JW Marriott Parq Vancouver', 'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BOiesoxuUF_FEZIWIDzqeQ/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/jw-marriott-parq-vancouver-vancouver?adjust_creative=5xMXIdPreqyQMiwJq_zdCg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=5xMXIdPreqyQMiwJq_zdCg', 'review_count': 90, 'categories': [{'alias': 'hotels', 'title': 'Hotels'}], 'rating': 4.0, 'coordinates': {'latitude': 49.2755820787777, 'longitude': -123.113645682597}, 'transactions': [], 'price': '$$$', 'location': {'address1': '39 Smithe Street', 'address2': None, 'address3': None, 'city': 'Vancouver', 'zip_code': 'V6B 0R3', 'country': 'CA', 'state': 'BC', 'display_address': ['39 Smithe Street', 'Vancouver, BC V6B 0R3', 'Canada']}, 'phone': '+16046760888', 'display_phone': '+1 604-676-0888', 'distance': 603.4721740196162}, {'id': 'D6LNse4cYkf_e-U6zJdgBA', 'alias': 'wedgewood-hotel-vancouver', 'name': 'Wedgewood Hotel', 'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DSDj0M0c0lag4M4361Acog/o.jpg', 'is_closed': False, 'url' ...

# %%
type(myresponse)
bus_array = myresponse['businesses']
len(bus_array)
# Out:
# 50

# %%
# Define Yelp query string categories / category names that will be sent in GET requests
# Adjusted - this was too many API calls
# category_mapping = {
#     "beaches,parks": "Beaches, Parks",
#     "bicyclepaths,mountainbiking": "Bicycle Paths, Mountain Biking",
#     "museums": "Museums",
#     "coffee": "Coffee & Tea",
#     "juicebars": "Juice Bars & Smoothies",
#     "hostels,hotels": "Hotels, Hotels"
# }

# Temporary 2nd YELP KEY with jtwleung:  TODO:  Don't forget to delete below
#YELP_KEY = 'wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'

# Categories - 3 API calls for each station_id (each of these strings for categories= in the query parameter)
categories = ['beaches,parks,bicyclepaths,mountainbiking', 'museums', 'hostels,hotels']

# Set Default Radius
radius = 1000

# Load the citybikes dataframe
stations_df = pd.read_csv('../data/citybikes_vancouver.csv')

# Generate the list of station_ids
station_ids_list = stations_df['id'].tolist()
station_ids_list = sorted(station_ids_list)

# Break into partition sizes to maximize usage of Yelp's 500 daily call limit (resets at 6pm Mountain == midnight UTC) and 3 calls per station_id in 245 stations
partition_1_size = 122
partition_2_size = 36

partition_1 = station_ids_list[:partition_1_size]
partition_2 = station_ids_list[partition_1_size: partition_1_size + partition_2_size]
partition_3 = station_ids_list[partition_1_size + partition_2_size:]  # is 87 ids long

# Set up an empty dataframe 'rolling_df' which will collect each individual API call into the larger dataframe
rolling_df = pd.DataFrame()

#for station_id in station_ids_list:  # Can't use this because Yelp's daily limit will cause this to fail mid-way
#for station_id in partition_1:  # Used this on 2023-10-19
#for station_id in partition_2:  # Used this on 2023-10-19 to hit remainder of calls for the day
for station_id in partition_3:  # Used this on 2023-10-20 to hit remainder of calls for the day
    print(f"************** New Station! **************")
    for entry_category in categories:
        filt_station = (stations_df['id'] == station_id)
        station_lat = stations_df.loc[filt_station]['lat'].values[0]
        station_long = stations_df.loc[filt_station]['long'].values[0]
        print (f"Working on station_id: {station_id}, categories being sent is: {entry_category}")
        print (f"     station_lat, station_long = ({station_lat}, {station_long})")

        # Call the function to do YELP GET request from the API
        #payload_dict = yelp_get_request_business_search(station_lat, station_long, radius, entry_category, YELP_KEY)
        
        # Define/reset the yelpdict dictionary, which holds the parsed JSON from the REST GET API call
        yelpdict = dict()
        create_default_yelpdict(yelpdict)

        # Parse the JSON from the payload from the API call
        yelpdict_from_response(station_id, yelpdict, payload_dict, entry_category)
        
        # Create a temp_df dataframe
        temp_df = pd.DataFrame(yelpdict)

        # Add the just-generated dataframe from this singular previous API call, to the cumulative "rolling_df" dataframe for the entirety of the station_ids
        rolling_df = pd.concat([rolling_df, temp_df], ignore_index=True)
# Out:
# ************** New Station! **************
# Working on station_id: a74744ce4bb7ea2aa9f406ac8bff95d8, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.280977, -123.035969)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.280977&longitude=-123.035969&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: a74744ce4bb7ea2aa9f406ac8bff95d8, categories being sent is: museums
#      station_lat, station_long = (49.280977, -123.035969)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.280977&longitude=-123.035969&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: a74744ce4bb7ea2aa9f406ac8bff95d8, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.280977, -123.035969)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.280977&longitude=-123.035969&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: a9f0b06d07f89b75e92c0cf686223aea, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.285953, -123.124066)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.285953&longitude=-123.124066&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: a9f0b06d07f89b75e92c0cf686223aea, categories being sent is: museums
#      station_lat, station_long = (49.285953, -123.124066)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.285953&longitude=-123.124066&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: a9f0b06d07f89b75e92c0cf686223aea, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.285953, -123.124066)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.285953&longitude=-123.124066&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: aa1cbf97abc3cd50515bc54633a9bb2a, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.2856698, -123.1125432)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.2856698&longitude=-123.1125432&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: aa1cbf97abc3cd50515bc54633a9bb2a, categories being sent is: museums
#      station_lat, station_long = (49.2856698, -123.1125432)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.2856698&longitude=-123.1125432&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: aa1cbf97abc3cd50515bc54633a9bb2a, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.2856698, -123.1125432)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.2856698&longitude=-123.1125432&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: aa704bfba40286bd0661b64d1f75e778, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.275717, -123.142564)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.275717&longitude=-123.142564&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: aa704bfba40286bd0661b64d1f75e778, categories being sent is: museums
#      station_lat, station_long = (49.275717, -123.142564)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.275717&longitude=-123.142564&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: aa704bfba40286bd0661b64d1f75e778, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.275717, -123.142564)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.275717&longitude=-123.142564&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: abfaf72456a4828a22f5bf60d3a80777, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.264326, -123.164725)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.264326&longitude=-123.164725&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: abfaf72456a4828a22f5bf60d3a80777, categories being sent is: museums
#      station_lat, station_long = (49.264326, -123.164725)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.264326&longitude=-123.164725&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: abfaf72456a4828a22f5bf60d3a80777, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.264326, -123.164725)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.264326&longitude=-123.164725&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: ac3b8198f03754a0afb8b6ed6d220cdd, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.274881, -123.069323)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.274881&longitude=-123.069323&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: ac3b8198f03754a0afb8b6ed6d220cdd, categories being sent is: museums
#      station_lat, station_long = (49.274881, -123.069323)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.274881&longitude=-123.069323&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: ac3b8198f03754a0afb8b6ed6d220cdd, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.274881, -123.069323)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.274881&longitude=-123.069323&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: ace20c241ee38643c9060f290b215b9d, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.265071, -123.123864)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.265071&longitude=-123.123864&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: ace20c241ee38643c9060f290b215b9d, categories being sent is: museums
#      station_lat, station_long = (49.265071, -123.123864)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.265071&longitude=-123.123864&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: ace20c241ee38643c9060f290b215b9d, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.265071, -123.123864)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.265071&longitude=-123.123864&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: ae69aeab748d02e5a7d89da28a1a8511, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.273691, -123.102232)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.273691&longitude=-123.102232&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: ae69aeab748d02e5a7d89da28a1a8511, categories being sent is: museums
#      station_lat, station_long = (49.273691, -123.102232)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.273691&longitude=-123.102232&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: ae69aeab748d02e5a7d89da28a1a8511, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.273691, -123.102232)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.273691&longitude=-123.102232&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: aed214941445e0345aa3254805a9e8b8, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.280197, -123.065859)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.280197&longitude=-123.065859&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: aed214941445e0345aa3254805a9e8b8, categories being sent is: museums
#      station_lat, station_long = (49.280197, -123.065859)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.280197&longitude=-123.065859&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: aed214941445e0345aa3254805a9e8b8, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.280197, -123.065859)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.280197&longitude=-123.065859&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: afacb2133f2462aba7748cc21b71c788, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.25741, -123.148531)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.25741&longitude=-123.148531&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: afacb2133f2462aba7748cc21b71c788, categories being sent is: museums
#      station_lat, station_long = (49.25741, -123.148531)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.25741&longitude=-123.148531&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: afacb2133f2462aba7748cc21b71c788, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.25741, -123.148531)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.25741&longitude=-123.148531&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b07d513f87897cff7319a0e59d7e567c, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.270877, -123.115103)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.270877&longitude=-123.115103&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b07d513f87897cff7319a0e59d7e567c, categories being sent is: museums
#      station_lat, station_long = (49.270877, -123.115103)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.270877&longitude=-123.115103&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b07d513f87897cff7319a0e59d7e567c, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.270877, -123.115103)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.270877&longitude=-123.115103&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b10d422b045805f1c350c47c983381e8, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.279235, -123.087528)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.279235&longitude=-123.087528&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b10d422b045805f1c350c47c983381e8, categories being sent is: museums
#      station_lat, station_long = (49.279235, -123.087528)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.279235&longitude=-123.087528&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b10d422b045805f1c350c47c983381e8, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.279235, -123.087528)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.279235&longitude=-123.087528&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b26f83e904f3a778466ebcd763b7316a, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.245135, -123.116098)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.245135&longitude=-123.116098&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b26f83e904f3a778466ebcd763b7316a, categories being sent is: museums
#      station_lat, station_long = (49.245135, -123.116098)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.245135&longitude=-123.116098&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b26f83e904f3a778466ebcd763b7316a, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.245135, -123.116098)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.245135&longitude=-123.116098&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b2c6aaf2b4fa8937bfe3941c038683aa, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.261188, -123.066009)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.261188&longitude=-123.066009&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b2c6aaf2b4fa8937bfe3941c038683aa, categories being sent is: museums
#      station_lat, station_long = (49.261188, -123.066009)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.261188&longitude=-123.066009&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b2c6aaf2b4fa8937bfe3941c038683aa, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.261188, -123.066009)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.261188&longitude=-123.066009&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b307709b305dd04328fbbf2c6db86419, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.277436, -123.070427)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.277436&longitude=-123.070427&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b307709b305dd04328fbbf2c6db86419, categories being sent is: museums
#      station_lat, station_long = (49.277436, -123.070427)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.277436&longitude=-123.070427&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b307709b305dd04328fbbf2c6db86419, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.277436, -123.070427)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.277436&longitude=-123.070427&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b30ed0719dd281867a4d39779c78b58a, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.258902, -123.109596)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.258902&longitude=-123.109596&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b30ed0719dd281867a4d39779c78b58a, categories being sent is: museums
#      station_lat, station_long = (49.258902, -123.109596)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.258902&longitude=-123.109596&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b30ed0719dd281867a4d39779c78b58a, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.258902, -123.109596)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.258902&longitude=-123.109596&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b3bb9f58d3530d33a1a09b6be9e973e0, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.282214, -123.114101)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.282214&longitude=-123.114101&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b3bb9f58d3530d33a1a09b6be9e973e0, categories being sent is: museums
#      station_lat, station_long = (49.282214, -123.114101)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.282214&longitude=-123.114101&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b3bb9f58d3530d33a1a09b6be9e973e0, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.282214, -123.114101)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.282214&longitude=-123.114101&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b428c0e64d9b9fdb3bf8e85c95ffdf6b, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.280852, -123.084746)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.280852&longitude=-123.084746&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b428c0e64d9b9fdb3bf8e85c95ffdf6b, categories being sent is: museums
#      station_lat, station_long = (49.280852, -123.084746)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.280852&longitude=-123.084746&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b428c0e64d9b9fdb3bf8e85c95ffdf6b, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.280852, -123.084746)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.280852&longitude=-123.084746&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b530d04d393d71cffb8b8b07f4a82380, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.282087, -123.056909)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.282087&longitude=-123.056909&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b530d04d393d71cffb8b8b07f4a82380, categories being sent is: museums
#      station_lat, station_long = (49.282087, -123.056909)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.282087&longitude=-123.056909&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b530d04d393d71cffb8b8b07f4a82380, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.282087, -123.056909)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.282087&longitude=-123.056909&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b562f08327af465e4531e20226789489, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.273103, -123.069892)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.273103&longitude=-123.069892&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b562f08327af465e4531e20226789489, categories being sent is: museums
#      station_lat, station_long = (49.273103, -123.069892)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.273103&longitude=-123.069892&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b562f08327af465e4531e20226789489, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.273103, -123.069892)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.273103&longitude=-123.069892&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b7683a86874e6300fd89f4cc0b075f57, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.275679, -123.116963)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.275679&longitude=-123.116963&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b7683a86874e6300fd89f4cc0b075f57, categories being sent is: museums
#      station_lat, station_long = (49.275679, -123.116963)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.275679&longitude=-123.116963&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b7683a86874e6300fd89f4cc0b075f57, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.275679, -123.116963)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.275679&longitude=-123.116963&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b7dd37a7dd668d6d10024b7f18acc438, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.2658, -123.20596)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.2658&longitude=-123.20596&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b7dd37a7dd668d6d10024b7f18acc438, categories being sent is: museums
#      station_lat, station_long = (49.2658, -123.20596)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.2658&longitude=-123.20596&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b7dd37a7dd668d6d10024b7f18acc438, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.2658, -123.20596)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.2658&longitude=-123.20596&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b9ab6ce009eda6006ade1d7568d9db9c, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.270905, -123.126006)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.270905&longitude=-123.126006&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b9ab6ce009eda6006ade1d7568d9db9c, categories being sent is: museums
#      station_lat, station_long = (49.270905, -123.126006)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.270905&longitude=-123.126006&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b9ab6ce009eda6006ade1d7568d9db9c, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.270905, -123.126006)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.270905&longitude=-123.126006&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b9baf685b7053de899bf3467f61c2781, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.267859, -123.145782)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.267859&longitude=-123.145782&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b9baf685b7053de899bf3467f61c2781, categories being sent is: museums
#      station_lat, station_long = (49.267859, -123.145782)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.267859&longitude=-123.145782&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b9baf685b7053de899bf3467f61c2781, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.267859, -123.145782)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.267859&longitude=-123.145782&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: b9fd847d53fe45658fee4c46e7f562b8, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.272827, -123.147744)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.272827&longitude=-123.147744&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b9fd847d53fe45658fee4c46e7f562b8, categories being sent is: museums
#      station_lat, station_long = (49.272827, -123.147744)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.272827&longitude=-123.147744&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: b9fd847d53fe45658fee4c46e7f562b8, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.272827, -123.147744)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.272827&longitude=-123.147744&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: bb0847559ce71c93d8215c0997ea2811, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.279369, -123.091241)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.279369&longitude=-123.091241&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: bb0847559ce71c93d8215c0997ea2811, categories being sent is: museums
#      station_lat, station_long = (49.279369, -123.091241)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.279369&longitude=-123.091241&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: bb0847559ce71c93d8215c0997ea2811, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.279369, -123.091241)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.279369&longitude=-123.091241&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: be14efdc86dedd6a8cd338e78ab4e7c7, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.28526, -123.141809)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.28526&longitude=-123.141809&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: be14efdc86dedd6a8cd338e78ab4e7c7, categories being sent is: museums
#      station_lat, station_long = (49.28526, -123.141809)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.28526&longitude=-123.141809&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: be14efdc86dedd6a8cd338e78ab4e7c7, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.28526, -123.141809)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.28526&longitude=-123.141809&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: bede4b24dae115d4cd43d2e6cc9812cb, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.261122, -123.097571)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.261122&longitude=-123.097571&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: bede4b24dae115d4cd43d2e6cc9812cb, categories being sent is: museums
#      station_lat, station_long = (49.261122, -123.097571)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.261122&longitude=-123.097571&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: bede4b24dae115d4cd43d2e6cc9812cb, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.261122, -123.097571)
# ...
# ************** New Station! **************
# Working on station_id: fad9ebcf614dd1a72593a34072ff76f8, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.279938, -123.127478)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.279938&longitude=-123.127478&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: fad9ebcf614dd1a72593a34072ff76f8, categories being sent is: museums
#      station_lat, station_long = (49.279938, -123.127478)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.279938&longitude=-123.127478&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: fad9ebcf614dd1a72593a34072ff76f8, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.279938, -123.127478)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.279938&longitude=-123.127478&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: fbb1d30d7f30b049873f5be5688563d4, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.28602, -123.116624)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.28602&longitude=-123.116624&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: fbb1d30d7f30b049873f5be5688563d4, categories being sent is: museums
#      station_lat, station_long = (49.28602, -123.116624)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.28602&longitude=-123.116624&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: fbb1d30d7f30b049873f5be5688563d4, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.28602, -123.116624)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.28602&longitude=-123.116624&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: fbb4c06b719596c21f91fd51ef6d4710, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.265089, -123.119425)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.265089&longitude=-123.119425&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: fbb4c06b719596c21f91fd51ef6d4710, categories being sent is: museums
#      station_lat, station_long = (49.265089, -123.119425)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.265089&longitude=-123.119425&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: fbb4c06b719596c21f91fd51ef6d4710, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.265089, -123.119425)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.265089&longitude=-123.119425&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: fe0c57d04d6e682d284d501446095fc9, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.277595, -123.09583)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.277595&longitude=-123.09583&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: fe0c57d04d6e682d284d501446095fc9, categories being sent is: museums
#      station_lat, station_long = (49.277595, -123.09583)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.277595&longitude=-123.09583&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: fe0c57d04d6e682d284d501446095fc9, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.277595, -123.09583)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.277595&longitude=-123.09583&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: fedff7a263c182df94bda7307059cc52, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.277141, -123.122589)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.277141&longitude=-123.122589&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: fedff7a263c182df94bda7307059cc52, categories being sent is: museums
#      station_lat, station_long = (49.277141, -123.122589)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.277141&longitude=-123.122589&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: fedff7a263c182df94bda7307059cc52, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.277141, -123.122589)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.277141&longitude=-123.122589&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: fef69fb400210d861107a61db954d037, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.279821, -123.10802)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.279821&longitude=-123.10802&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: fef69fb400210d861107a61db954d037, categories being sent is: museums
#      station_lat, station_long = (49.279821, -123.10802)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.279821&longitude=-123.10802&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: fef69fb400210d861107a61db954d037, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.279821, -123.10802)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.279821&longitude=-123.10802&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# ************** New Station! **************
# Working on station_id: fffd87607aaae16fbb1f71615cbe7d17, categories being sent is: beaches,parks,bicyclepaths,mountainbiking
#      station_lat, station_long = (49.263518, -123.09568)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.263518&longitude=-123.09568&radius=1000&categories=beaches,parks,bicyclepaths,mountainbiking&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: fffd87607aaae16fbb1f71615cbe7d17, categories being sent is: museums
#      station_lat, station_long = (49.263518, -123.09568)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.263518&longitude=-123.09568&radius=1000&categories=museums&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# Working on station_id: fffd87607aaae16fbb1f71615cbe7d17, categories being sent is: hostels,hotels
#      station_lat, station_long = (49.263518, -123.09568)
# Inside yelp_get_request: request_url = https://api.yelp.com/v3/businesses/search?latitude=49.263518&longitude=-123.09568&radius=1000&categories=hostels,hotels&limit=50&sort_by=best_match, header_dict = {'accept': 'application/json', 'Authorization': 'Bearer wHKvbUKt45iPv0vitouFdnQ5M75dq8bw8WD1RfBpIvE11xMwXATMRbsQ80iL9nKpVJU4JZKbINPdznr9DaMDbeWQ_prpxl3amhNLSVoaWBaOPTiSQen3SEZ0oCEyZXYx'}
# (2578, 12)
#                           station_id                place_id  \
# 0   a74744ce4bb7ea2aa9f406ac8bff95d8  EByyWFFnSnrmQZct_j6MBg
# 1   a74744ce4bb7ea2aa9f406ac8bff95d8  _BkYJw9plA2tYLoToa9mGQ
# 2   a74744ce4bb7ea2aa9f406ac8bff95d8  _UWGRNA9Jkbt72_3NXpNcw
# 3   a74744ce4bb7ea2aa9f406ac8bff95d8  d4PXZQGnXuCE7akD7PQ_TA
# 4   a74744ce4bb7ea2aa9f406ac8bff95d8  LBVCFvtVtDwzOc2R0EqwfA
# ..                               ...                     ...
# 95  aa1cbf97abc3cd50515bc54633a9bb2a  8snL4a-AN2JHWxgK62riUQ
# 96  aa1cbf97abc3cd50515bc54633a9bb2a  E1FGWviFkHNH9NfnxAEaVw
# 97  aa1cbf97abc3cd50515bc54633a9bb2a  KwMakQ-ozY7U7OySlRb-Kw
# 98  aa1cbf97abc3cd50515bc54633a9bb2a  1ZWwVOwu2BI7v7Hh-PlDGQ
# 99  aa1cbf97abc3cd50515bc54633a9bb2a  k3CmR5RiT3ulGJoT98D-Aw
#
#                                           name    distance  \
# 0                            New Brighton Park  948.481468
# 1                         Il Giardino Italiano   78.531770
# 2                                Hastings Park  291.862881
# 3                     Rupert Park Pitch & Putt  959.110609
# 4                                  Adanac Park  875.246088
# ..                                         ...         ...
# 95                     Hyatt Regency Vancouver  585.993327
# 96                    Executive Hotel LeSoleil  416.380860
# 97                           L'Hermitage Hotel  668.474308
# 98  Vancouver Marriott Pinnacle Downtown Hotel  651.654435
# 99                     Auberge Vancouver Hotel  211.022493
#
#                       address       city   postal  review_count  rating  \
# 0      3201 New Brighton Road  Vancouver  V5K 5J7          16.0     4.5
# 1          2901 E Hastings St  Vancouver  V5K 5J1           2.0     4.0
# 2      2901 E Hastings Street  Vancouver  V5K 5J1           9.0     4.0
# 3         3402 Charles Street  Vancouver  V5K 5H9           9.0     4.0
# 4          1025 Boundary Road  Vancouver  V5K 4T2           1.0     3.0
# ..                        ...        ...      ...           ...     ...
# 95         655 Burrard Street  Vancouver  V6C 2R7         302.0     4.0
# 96          567 Hornby Street  Vancouver  V6C 2E8          88.0     4.5
# 97        788 Richards Street  Vancouver  V6B 3A4         149.0     4.5
# 98  1128 West Hastings Street  Vancouver  V6E 4R5         185.0     4.0
# 99      837 W Hastings Street  Vancouver  V6C 2X1          24.0     4.0
#
#       category_id                 category_name  \
# 0   beaches|parks                 Beaches|Parks
# 1           parks                         Parks
# 2           parks                         Parks
# 3      parks|golf                    Parks|Golf
# 4           parks                         Parks
# ..            ...                           ...
# 95  hotels|venues  Hotels|Venues & Event Spaces
# 96         hotels                        Hotels
# 97         hotels                        Hotels
# 98         hotels                        Hotels
# 99         hotels                        Hotels
#
#                              query_categories
# 0   beaches,parks,bicyclepaths,mountainbiking
# 1   beaches,parks,bicyclepaths,mountainbiking
# 2   beaches,parks,bicyclepaths,mountainbiking
# 3   beaches,parks,bicyclepaths,mountainbiking
# 4   beaches,parks,bicyclepaths,mountainbiking
# ..                                        ...
# 95                             hostels,hotels
# 96                             hostels,hotels
# 97                             hostels,hotels
# 98                             hostels,hotels
# 99                             hostels,hotels
#
# [100 rows x 12 columns]

# %%
rolling_df['category_id'].value_counts()
# Out:
# category_id
# hotels                               1144
# parks                                 599
# museums                               116
# hotels|venues                         111
# hostels                               107
# hotels|bedbreakfast                    73
# dog_parks                              62
# parks|playgrounds                      48
# beaches                                22
# resorts|hotels|vacation_rentals        22
# gardens|parks                          20
# artmuseums                             19
# museums|galleries                      19
# catering|hotels                        18
# landmarks|parks                        17
# casinos|hotels|venues                  15
# playgrounds|dog_parks                  15
# beaches|parks                          15
# hotels|divebars                        12
# hiking|mountainbiking|bikerentals      12
# waterparks|parks|playgrounds           11
# parks|theater                          10
# museums|galleries|venues                9
# skate_parks                             9
# apartments|hotels                       9
# amateursportsteams|football|parks       9
# catering|shopping|hotels                7
# parks|lakes                             6
# hiking|parks                            6
# hotels|bedbreakfast|guesthouses         6
# parks|playgrounds|tennis                5
# parks|beaches                           4
# parks|arts                              4
# tennis|parks|playgrounds                3
# parks|playgrounds|lakes                 3
# tennis|parks                            3
# parks|swimmingpools                     2
# parks|gyms|recreation                   2
# parks|landmarks                         2
# mountainbiking                          1
# parks|golf                              1
# Name: count, dtype: int64

# %%
rolling_df.shape
rolling_df.head(50)
# Out:
#                           station_id                place_id  \
# 0   a74744ce4bb7ea2aa9f406ac8bff95d8  EByyWFFnSnrmQZct_j6MBg
# 1   a74744ce4bb7ea2aa9f406ac8bff95d8  _BkYJw9plA2tYLoToa9mGQ
# 2   a74744ce4bb7ea2aa9f406ac8bff95d8  _UWGRNA9Jkbt72_3NXpNcw
# 3   a74744ce4bb7ea2aa9f406ac8bff95d8  d4PXZQGnXuCE7akD7PQ_TA
# 4   a74744ce4bb7ea2aa9f406ac8bff95d8  LBVCFvtVtDwzOc2R0EqwfA
# 5   a74744ce4bb7ea2aa9f406ac8bff95d8  62f1QlwgVZr3pFHdjS542A
# 6   a74744ce4bb7ea2aa9f406ac8bff95d8  w_JY6JHlUtDw09puGdEPxw
# 7   a9f0b06d07f89b75e92c0cf686223aea  GlYICUHh-vsbdBsdjnRwMg
# 8   a9f0b06d07f89b75e92c0cf686223aea  -fHqwIU4S-uD9O-ouzhE_A
# 9   a9f0b06d07f89b75e92c0cf686223aea  KiRXFRtSzRbgU_55Nj845Q
# 10  a9f0b06d07f89b75e92c0cf686223aea  dtYmLpvyY0dwEFrYLSZZCQ
# 11  a9f0b06d07f89b75e92c0cf686223aea  tzUw_wiTr7CcDBKq4YK5XA
# 12  a9f0b06d07f89b75e92c0cf686223aea  XAKULkvx3NBAMoBZHov0xA
# 13  a9f0b06d07f89b75e92c0cf686223aea  07geewQvderr61mRx9mjmA
# 14  a9f0b06d07f89b75e92c0cf686223aea  5-3wyrIOYInzwEZHTQP9nw
# 15  a9f0b06d07f89b75e92c0cf686223aea  FqPfBcBh9r_HmW6FZA1_gQ
# 16  a9f0b06d07f89b75e92c0cf686223aea  FpXp_Knu7QK5AI-vbZTKBA
# 17  a9f0b06d07f89b75e92c0cf686223aea  bFQBBVUNF3wY6e4RMysDxw
# 18  a9f0b06d07f89b75e92c0cf686223aea  -nnbiBMMbT5gj4zVnxvyuA
# 19  a9f0b06d07f89b75e92c0cf686223aea  42Tg2jf217mRb_rqYpKAbw
# 20  a9f0b06d07f89b75e92c0cf686223aea  h7H3QdzykDSYzY29Hk3LvQ
# 21  a9f0b06d07f89b75e92c0cf686223aea  f1H0R3PH2JY2z6eo6U3w1A
# 22  a9f0b06d07f89b75e92c0cf686223aea  O0Zly_wPXAYsl57__GKzww
# 23  a9f0b06d07f89b75e92c0cf686223aea  MvZWVmSAsTKKYuHPOcAkXQ
# 24  a9f0b06d07f89b75e92c0cf686223aea  eZzkZw5KCDreq7kor4_WUg
# 25  a9f0b06d07f89b75e92c0cf686223aea  8snL4a-AN2JHWxgK62riUQ
# 26  a9f0b06d07f89b75e92c0cf686223aea  WGdCrG3tW3RIlnZkaA5I8A
# 27  a9f0b06d07f89b75e92c0cf686223aea  1ZWwVOwu2BI7v7Hh-PlDGQ
# 28  a9f0b06d07f89b75e92c0cf686223aea  tVtabcnjDgscp7g54HdTdw
# 29  a9f0b06d07f89b75e92c0cf686223aea  wfBQO46asX0DLpS0SlSACw
# 30  a9f0b06d07f89b75e92c0cf686223aea  jBxdh-9KXvNf5YUBsxTP0g
# 31  a9f0b06d07f89b75e92c0cf686223aea  4mR255_3-j7g24ZylLFX2A
# 32  a9f0b06d07f89b75e92c0cf686223aea  D6LNse4cYkf_e-U6zJdgBA
# 33  a9f0b06d07f89b75e92c0cf686223aea  ESYgaAU5w7wdvhhHs3Wwsg
# 34  a9f0b06d07f89b75e92c0cf686223aea  kmlTLQBg8Ujh75_UZrmRWw
# 35  a9f0b06d07f89b75e92c0cf686223aea  PSoOJqgIXe7z9_Wpbb_Lxw
# 36  a9f0b06d07f89b75e92c0cf686223aea  E1FGWviFkHNH9NfnxAEaVw
# 37  a9f0b06d07f89b75e92c0cf686223aea  KwMakQ-ozY7U7OySlRb-Kw
# 38  a9f0b06d07f89b75e92c0cf686223aea  CmaaIg045RLf7ne5cjEP8A
# 39  a9f0b06d07f89b75e92c0cf686223aea  kYaGwhd_syg63_9nY0JtDQ
# 40  a9f0b06d07f89b75e92c0cf686223aea  YdNYxAdL8oHmFPp8SOw_wg
# 41  a9f0b06d07f89b75e92c0cf686223aea  EOwOJWs29mAT4XK4QaDPdA
# 42  a9f0b06d07f89b75e92c0cf686223aea  qX2ujLB8KnjGQvTKX7dbFQ
# 43  a9f0b06d07f89b75e92c0cf686223aea  UuT87K7cBklh57XTVSKfMw
# 44  a9f0b06d07f89b75e92c0cf686223aea  QlAT8YnelUU02uBF_Q_8Cw
# 45  a9f0b06d07f89b75e92c0cf686223aea  xgmZLXklsI4gAmJ0HtyDIg
# 46  a9f0b06d07f89b75e92c0cf686223aea  dD2gesRGWMBnk3V_3djvIw
# 47  a9f0b06d07f89b75e92c0cf686223aea  V905IuasCwIRKqGaE5SljQ
# 48  a9f0b06d07f89b75e92c0cf686223aea  Mc_r7aQX98IIBS9PNoU66Q
# 49  a9f0b06d07f89b75e92c0cf686223aea  9tshb1PcMax8HnRloxMNnA
#
#                                                  name     distance  \
# 0                                   New Brighton Park   948.481468
# 1                                Il Giardino Italiano    78.531770
# 2                                       Hastings Park   291.862881
# 3                            Rupert Park Pitch & Putt   959.110609
# 4                                         Adanac Park   875.246088
# 5                                      Callister Park   894.985004
# 6                                          Atrium Inn   679.261964
# 7                                  Harbour Green Park   415.206448
# 8                                        Rainbow Park   847.369121
# 9                                         Portal Park   428.915352
# 10                                        Nelson Park   541.431481
# 11                     Davie Village Community Garden   812.736610
# 12                            Barclay Heritage Square   601.289106
# 13                      Smithe-Richards Downtown Park   844.354230
# 14                                      Yaletown Park  1062.542132
# 15                              Devonian Harbour Park  1212.111105
# 16                                      Barclay Manor   636.742140
# 17                                  Rotery Beach Park  1002.475674
# 18                                   Cathedral Square   837.378995
# 19  Stanley Park Shuffleboard Court Area - Gated O...  1336.183174
# 20                              Vancouver Art Gallery   422.689928
# 21           Bill Reid Gallery of Northwest Coast Art   369.085569
# 22                                Roedde House Museum   592.374961
# 23                                         Shangri-La    34.318188
# 24                                        Loden Hotel   194.397138
# 25                            Hyatt Regency Vancouver   270.070556
# 26                            Paradox Hotel Vancouver    83.420527
# 27         Vancouver Marriott Pinnacle Downtown Hotel   318.750756
# 28                                 Blue Horizon Hotel   238.648401
# 29          Coast Coal Harbour Vancouver Hotel by APA   293.873813
# 30                               Fairmont Pacific Rim   564.030519
# 31                           Fairmont Hotel Vancouver   341.695320
# 32                                    Wedgewood Hotel   409.476894
# 33                             Rosewood Hotel Georgia   453.213558
# 34                             The Sutton Place Hotel   359.025678
# 35                        Pinnacle Hotel Harbourfront   377.199940
# 36                           Executive Hotel LeSoleil   427.340650
# 37                                  L'Hermitage Hotel   810.959300
# 38                                   The Listel Hotel   381.120728
# 39                                    St. Regis Hotel   677.274334
# 40                                Fairmont Waterfront   750.809592
# 41                               West End Guest House   508.022193
# 42                              Pan Pacific Vancouver   798.229308
# 43                     The Westin Bayshore, Vancouver   820.110443
# 44        Georgian Court Hotel, BW Premier Collection  1144.999587
# 45                     Sheraton Vancouver Wall Centre   651.100378
# 46                                      Carmana Plaza    50.343434
# 47                             Residence Inn Marriott   954.677024
# 48                                        The Burrard   727.316512
# 49  Hampton Inn & Suites by Hilton Vancouver-Downtown  1160.175354
#
#                       address       city   postal  review_count  rating  \
# 0      3201 New Brighton Road  Vancouver  V5K 5J7          16.0     4.5
# 1          2901 E Hastings St  Vancouver  V5K 5J1           2.0     4.0
# 2      2901 E Hastings Street  Vancouver  V5K 5J1           9.0     4.0
# 3         3402 Charles Street  Vancouver  V5K 5H9           9.0     4.0
# 4          1025 Boundary Road  Vancouver  V5K 4T2           1.0     3.0
# 5          2875 Oxford Street  Vancouver  V5K 1N6           1.0     3.0
# 6   2889 East Hastings Street  Vancouver  V5K 2A1          58.0     3.0
# 7       1199 W Cordova Street  Vancouver  V6C 0A1          15.0     4.5
# 8         872 Richards Street  Vancouver  V6B 3B4           4.0     5.0
# 9      1099 W Hastings Street  Vancouver  V6E 4E2           1.0     5.0
# 10               1030 Bute St  Vancouver      V6E          27.0     3.5
# 11    Davie St And Burrard St  Vancouver  V6Z 1Y9           5.0     2.0
# 12        1433 Barclay Street  Vancouver  V6G 1J6           1.0     4.0
# 13            872 Richards St  Vancouver  V6B 3B4           1.0     5.0
# 14        901 Mainland Street  Vancouver  V6B 1T2           8.0     2.0
# 15      1929 W Georgia Street  Vancouver  V6G 2W9           1.0     4.0
# 16        1447 Barclay Street  Vancouver  V6G 1J6           1.0     4.0
# 17      Richards Davie Street  Vancouver  V6E 4L2           1.0     3.0
# 18        566 Richards Street  Vancouver  V6B 1X4           2.0     3.0
# 19      2000 W Georgia Street  Vancouver      V6G           1.0     3.0
# 20          750 Hornby Street  Vancouver  V6Z 2H7         188.0     3.5
# 21          639 Hornby Street  Vancouver  V6C 2G3          14.0     4.5
# 22        1415 Barclay Street  Vancouver  V6G 1J6          13.0     4.0
# 23      1128 W Georgia Street  Vancouver  V6E 0A8         105.0     4.5
# 24       1177 Melville Street  Vancouver  V6E 0A3         154.0     4.5
# 25         655 Burrard Street  Vancouver  V6C 2R7         302.0     4.0
# 26      1161 W Georgia Street  Vancouver  V6E 0C6          21.0     4.5
# 27  1128 West Hastings Street  Vancouver  V6E 4R5         185.0     4.0
# 28         1225 Robson Street  Vancouver  V6E 1C2         138.0     4.0
# 29         1180 West Hastings  Vancouver  V6E 4R5          85.0     4.0
# 30      1038 Canada Place Way  Vancouver  V6C 0B9         257.0     4.5
# 31    900 West Georgia Street  Vancouver  V6C 2W6         255.0     3.5
# 32          845 Hornby Street  Vancouver  V6Z 1V1          79.0     4.5
# 33       801 W Georgia Street  Vancouver  V6C 1P7         124.0     4.5
# 34             845 Burrard St  Vancouver  V6Z 2K6         255.0     4.0
# 35     1133 W Hastings Street  Vancouver  V6E 3T3         136.0     3.5
# 36          567 Hornby Street  Vancouver  V6C 2E8          88.0     4.5
# 37        788 Richards Street  Vancouver  V6B 3A4         149.0     4.5
# 38             1300 Robson St  Vancouver  V6E 1C5         131.0     4.0
# 39        602 Dunsmuir Street  Vancouver  V6B 1Y6          91.0     4.5
# 40       900 Canada Place Way  Vancouver  V6C 3L5         141.0     4.0
# 41               1362 Haro St  Vancouver  V6E 1G2          29.0     4.5
# 42           999 Canada Place  Vancouver  V6C 3B5         233.0     4.0
# 43        1601 Bayshore Drive  Vancouver  V6G 2V4         216.0     4.0
# 44              773 Beatty St  Vancouver  V6B 2M4         108.0     4.0
# 45        1000 Burrard Street  Vancouver  V6Z 2R9         227.0     3.5
# 46        1128 Alberni Street  Vancouver  V6E 4R6          15.0     3.5
# 47         1234 Hornby Street  Vancouver  V6Z 1W2         118.0     4.0
# 48        1100 Burrard Street  Vancouver  V6Z 1Y7         117.0     4.0
# 49          111 Robson Street  Vancouver  V6B 2A8          70.0     4.0
#
#             category_id                 category_name  \
# 0         beaches|parks                 Beaches|Parks
# 1                 parks                         Parks
# 2                 parks                         Parks
# 3            parks|golf                    Parks|Golf
# 4                 parks                         Parks
# 5                 parks                         Parks
# 6         hotels|venues  Hotels|Venues & Event Spaces
# 7                 parks                         Parks
# 8                 parks                         Parks
# 9                 parks                         Parks
# 10            dog_parks                     Dog Parks
# 11        gardens|parks       Botanical Gardens|Parks
# 12                parks                         Parks
# 13    parks|playgrounds             Parks|Playgrounds
# 14                parks                         Parks
# 15                parks                         Parks
# 16                parks                         Parks
# 17                parks                         Parks
# 18                parks                         Parks
# 19            dog_parks                     Dog Parks
# 20           artmuseums                   Art Museums
# 21    museums|galleries         Museums|Art Galleries
# 22              museums                       Museums
# 23               hotels                        Hotels
# 24               hotels                        Hotels
# 25        hotels|venues  Hotels|Venues & Event Spaces
# 26               hotels                        Hotels
# 27               hotels                        Hotels
# 28               hotels                        Hotels
# 29        hotels|venues  Hotels|Venues & Event Spaces
# 30               hotels                        Hotels
# 31               hotels                        Hotels
# 32               hotels                        Hotels
# 33               hotels                        Hotels
# 34               hotels                        Hotels
# 35               hotels                        Hotels
# 36               hotels                        Hotels
# 37               hotels                        Hotels
# 38      catering|hotels               Caterers|Hotels
# 39               hotels                        Hotels
# 40               hotels                        Hotels
# 41  hotels|bedbreakfast        Hotels|Bed & Breakfast
# 42               hotels                        Hotels
# 43               hotels                        Hotels
# 44               hotels                        Hotels
# 45               hotels                        Hotels
# 46               hotels                        Hotels
# 47               hotels                        Hotels
# 48               hotels                        Hotels
# 49               hotels                        Hotels
#
#                              query_categories
# 0   beaches,parks,bicyclepaths,mountainbiking
# 1   beaches,parks,bicyclepaths,mountainbiking
# 2   beaches,parks,bicyclepaths,mountainbiking
# 3   beaches,parks,bicyclepaths,mountainbiking
# 4   beaches,parks,bicyclepaths,mountainbiking
# 5   beaches,parks,bicyclepaths,mountainbiking
# 6                              hostels,hotels
# 7   beaches,parks,bicyclepaths,mountainbiking
# 8   beaches,parks,bicyclepaths,mountainbiking
# 9   beaches,parks,bicyclepaths,mountainbiking
# 10  beaches,parks,bicyclepaths,mountainbiking
# 11  beaches,parks,bicyclepaths,mountainbiking
# 12  beaches,parks,bicyclepaths,mountainbiking
# 13  beaches,parks,bicyclepaths,mountainbiking
# 14  beaches,parks,bicyclepaths,mountainbiking
# 15  beaches,parks,bicyclepaths,mountainbiking
# 16  beaches,parks,bicyclepaths,mountainbiking
# 17  beaches,parks,bicyclepaths,mountainbiking
# 18  beaches,parks,bicyclepaths,mountainbiking
# 19  beaches,parks,bicyclepaths,mountainbiking
# 20                                    museums
# 21                                    museums
# 22                                    museums
# 23                             hostels,hotels
# 24                             hostels,hotels
# 25                             hostels,hotels
# 26                             hostels,hotels
# 27                             hostels,hotels
# 28                             hostels,hotels
# 29                             hostels,hotels
# 30                             hostels,hotels
# 31                             hostels,hotels
# 32                             hostels,hotels
# 33                             hostels,hotels
# 34                             hostels,hotels
# 35                             hostels,hotels
# 36                             hostels,hotels
# 37                             hostels,hotels
# 38                             hostels,hotels
# 39                             hostels,hotels
# 40                             hostels,hotels
# 41                             hostels,hotels
# 42                             hostels,hotels
# 43                             hostels,hotels
# 44                             hostels,hotels
# 45                             hostels,hotels
# 46                             hostels,hotels
# 47                             hostels,hotels
# 48                             hostels,hotels
# 49                             hostels,hotels

# %%
# Save the individual partitioned dataframes as .csv files

#rolling_df.to_csv('../data/yelp_vancouver_partition1.csv', index=False)  # Saved on 2023-10-20 evening for partition_1
#rolling_df.to_csv('../data/yelp_vancouver_partition2.csv', index=False)  # Saved on 2023-10-20 evening for partition_2
#rolling_df.to_csv('../data/yelp_vancouver_partition3.csv', index=False)  # Saved on 2023-10-21 for partition_3

# %%
# Calculations required to support breaking station_id list into partition sizes to maximize usage of Yelp's 500 daily call limit
# (resets at 6pm Mountain == midnight UTC) and 3 calls per station_id in 245 stations
partition_1_size = 122
partition_2_size = 36

partition_1 = station_ids_list[:partition_1_size]
partition_2 = station_ids_list[partition_1_size: partition_1_size + partition_2_size]
partition_3 = station_ids_list[partition_1_size + partition_2_size:]

print(len(partition_1))
print(len(partition_2))
print(len(partition_3))

total_ids_in_partitions = len(partition_1) + len(partition_2) + len(partition_3)
print(f"total ids in all partitions ({total_ids_in_partitions}) == stations_df.shape[0]: {total_ids_in_partitions == stations_df.shape[0]}")
# Out:
# 122
# 36
# 87
# total ids in all partitions (245) == stations_df.shape[0]: True

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# Need to pull each of the 3 partitions from 3 .csv files, into a singular dataframe for Yelp
partition1_df = pd.read_csv('../data/yelp_vancouver_partition1.csv')
partition2_df = pd.read_csv('../data/yelp_vancouver_partition2.csv')
partition3_df = pd.read_csv('../data/yelp_vancouver_partition3.csv')

yelp_df = pd.concat([partition1_df, partition2_df, partition3_df], ignore_index=True)

# %%
yelp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6684 entries, 0 to 6683
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station_id        6684 non-null   object
#  1   place_id          6684 non-null   object
#  2   name              6684 non-null   object
#  3   distance          6684 non-null   float64
#  4   address           6644 non-null   object
#  5   city              6684 non-null   object
#  6   postal            6659 non-null   object
#  7   review_count      6684 non-null   float64
#  8   rating            6684 non-null   float64
#  9   category_id       6684 non-null   object
#  10  category_name     6684 non-null   object
#  11  query_categories  6684 non-null   object
# dtypes: float64(3), object(9)
# memory usage: 626.8+ KB

# %%
yelp_df.head(10)
# Out:
#                          station_id                place_id  \
# 0  00fa94ad698dc4a9e4d708d6fd32f294  kajMc2fkWKdzKJ1M4pm47Q
# 1  00fa94ad698dc4a9e4d708d6fd32f294  VoziJj_Fw67OtZtdDzrpQg
# 2  00fa94ad698dc4a9e4d708d6fd32f294  XHJTdq8QJp6_9oCj5hU85w
# 3  00fa94ad698dc4a9e4d708d6fd32f294  EGZABxCmlA3PNwbSYXhLbA
# 4  00fa94ad698dc4a9e4d708d6fd32f294  AVulOVkLG2LIRaOdOAmdlA
# 5  00fa94ad698dc4a9e4d708d6fd32f294  2CxBAbnFIOfjRASbWcHC4w
# 6  00fa94ad698dc4a9e4d708d6fd32f294  4563XS_PrPJivPv_R5sW3Q
# 7  00fa94ad698dc4a9e4d708d6fd32f294  kRl_c-eObP6vf3KbJ0fulw
# 8  00fa94ad698dc4a9e4d708d6fd32f294  42Tg2jf217mRb_rqYpKAbw
# 9  00fa94ad698dc4a9e4d708d6fd32f294  TBcn1EwTCv3EsF4SEI3s4w
#
#                                                 name     distance  \
# 0                                       Stanley Park   978.386841
# 1                             English Bay Beach Park   783.428693
# 2                                  Vancouver Seawall   663.404115
# 3                                        Morton Park   426.335401
# 4                                        Lost Lagoon   328.531508
# 5                 Stanley Park 2nd Beach Picnic Area   715.128216
# 6                                     Alexandra Park   721.708957
# 7                                 Movies in the Park   701.088810
# 8  Stanley Park Shuffleboard Court Area - Gated O...   395.498272
# 9                                  Lovers Walk Trail  1287.417500
#
#                    address       city   postal  review_count  rating  \
# 0  1166 Stanley Park Drive  Vancouver      V6G        1091.0     5.0
# 1        1700 Beach Avenue  Vancouver  V6E 1V3          68.0     4.5
# 2                      NaN  Vancouver      NaN         101.0     5.0
# 3       1800 Morton Avenue  Vancouver  V6G 1Z1          14.0     4.5
# 4                Lagoon Dr  Vancouver      V6G          18.0     4.5
# 5        Ceperly 2nd Beach  Vancouver  V6G 3E2           8.0     3.5
# 6        1755 Beach avenue  Vancouver  V6E 1V3           1.0     5.0
# 7          Stanley Park Dr  Vancouver      V6G           6.0     4.5
# 8    2000 W Georgia Street  Vancouver      V6G           1.0     3.0
# 9              Lovers Walk  Vancouver      V6G           2.0     5.0
#
#     category_id               category_name  \
# 0         parks                       Parks
# 1         parks                       Parks
# 2  hiking|parks                Hiking|Parks
# 3         parks                       Parks
# 4   parks|lakes                 Parks|Lakes
# 5       beaches                     Beaches
# 6         parks                       Parks
# 7    parks|arts  Parks|Arts & Entertainment
# 8     dog_parks                   Dog Parks
# 9  hiking|parks                Hiking|Parks
#
#                             query_categories
# 0  beaches,parks,bicyclepaths,mountainbiking
# 1  beaches,parks,bicyclepaths,mountainbiking
# 2  beaches,parks,bicyclepaths,mountainbiking
# 3  beaches,parks,bicyclepaths,mountainbiking
# 4  beaches,parks,bicyclepaths,mountainbiking
# 5  beaches,parks,bicyclepaths,mountainbiking
# 6  beaches,parks,bicyclepaths,mountainbiking
# 7  beaches,parks,bicyclepaths,mountainbiking
# 8  beaches,parks,bicyclepaths,mountainbiking
# 9  beaches,parks,bicyclepaths,mountainbiking

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# 1. Look at the difference in number and granularity of categories (eye-ball):'
# Yelp:  https://docs.developer.yelp.com/docs/resources-categories
# Foursquare:  https://location.foursquare.com/places/docs/categories
#
# 2.  Look at the different types of APIs:
# Yelp:
# APIs (Yelp Fusion) Overview:  https://docs.developer.yelp.com/docs/fusion-intro
#     - Can get Businesses, Reviews, Events, Available Categories, Brands, and Autocomplete (typeahead search service)
#     - Out of the above, the "Businesses Search" (https://docs.developer.yelp.com/reference/v3_business_search) seems most useful
#         - Limitation:  Won't return any businesses without reviews
#         - Accepts lat & long
#         - Has Max 50 limit
#     - "Businesses Reviews" (https://docs.developer.yelp.com/reference/v3_business_reviews) could be useful, but only returns up to 3 review exercepts and does not return businesses without reviews, which could be limiting.
#         -The fact it returns up to 3 reviews will skew our data because businesses that are very popular with more than 3 reviews won't be differentiable in the dataset.
#         - It does not seem to return review ratings/numbers so it's not that easy or accurate to easily generate a sentiment, either, for use in a model
#     - Events Search (https://docs.developer.yelp.com/reference/v3_events_search) could be useful to see if more events in the immediate station radius would impact how many
#         - TODO: Will need to determine if it gives all events across the year, or only within a certain timeframe around the request time (which is less useful for statistical model)
#         - 50 limit may be limiting
#
#
# Foursquare:
# APIs Overview:  https://location.foursquare.com/developer/reference/api-overview
#     - Places API:  https://location.foursquare.com/developer/reference/places-api-overview#endpoints
#         - Place Search (https://location.foursquare.com/developer/reference/place-search):  "Search for places in the FSQ Places database using a location and querying by name, category name, telephone number, taste label, or chain name. For example, search for "coffee" to get back a list of recommended coffee shops ... You may pass a location with your request by using one of the following options."
#         - Place Details (https://location.foursquare.com/developer/reference/place-details):  "Retrieve comprehensive information and metadata for a FSQ Place using the fsq_id."
#         - Place Photos (https://location.foursquare.com/developer/reference/place-photos):  "Retrieve photos for a FSQ Place using the fsq_id."
#         - Place Tips (https://location.foursquare.com/developer/reference/place-tips):  "Retrieve tips for a FSQ Place using the fsq_id."
#         - Place Match (https://location.foursquare.com/developer/reference/place-match): "Return the Foursquare record of a POI (via FSQ_ID) given a Name and Location. Provide a Location by using all the Address parameters, or by LL."
#     - Studio Data API (geospatial assets - not useful to us for this exercise)
#     - Geofence API (user-configured geofences - not useful to us for this exercise)
#
#     - The Places API and MAYBE the Place Tips would be the most useful to us.  How many categories available would be next.  Max 50 limit in return string could be a limiting factor.
#
# OVERALL:
# - Yelp has better, richer data set (example:  'coffee' for station_id 1 maxxed over 50 results, whereas Foursquare '13032' for same location returned fewer results, within the 50 limit).
# - But I am NOT going to use Yelp because the API limit call (500 per day) means I cannot break the categories apart (I will run out of calls) and am more likely to max out, so my dataset is questionable in its completeness.  Running a linear regression on "number of bikes available for rent at a given station, as a function of how many POIs within 1km radius of station" becomes problematic when numerous of the POI counts are at 50 but we don't know how much over 50.
# - Because I had more calls on Foursquare available to me, I could make more calls for individual categories (especially breaking out the "Outdoor" and less likely to max out because I'm not combining multiple subcategories together).  This dataset is more reliable even though it doesn't have ratings.  I will be using the Foursquare dataset primarily for my regression/statistical model building.

# %% [markdown]
# Get the top 10 restaurants according to their rating
